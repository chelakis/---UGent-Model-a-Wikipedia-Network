# %%
from bs4 import BeautifulSoup as bs
# !pip3 install networkx
# !pip3 install matplotlib
import requests


next_page = "https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen" #starting wikipedia page
a_links = [] #table of Wikipedia articles
b_links = []

flag = True #boolean
dict = {}

while flag: 

    res = requests.get(next_page)  #request page
#     print(res.text)
    soup = bs(res.text, "html.parser") #beautiful page constructor
    flag = False 
    for link in soup.find_all("a"): #finds all the "a" classes in the webpage

        url = link.get("href", "") #gets all the hyperlinks from the "a" class
#         print(url)
        if "Volgende zied" in link.text.strip(): #if the link leads to the next page of all articles
            next_page = "https://nds-nl.wikipedia.org" + url #change the starting wikipedia page to the next one
            print (next_page)
            flag = True  #change flag to true
            continue 

        if url=="https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen": #if last page break
            break

        if "/wiki" in url: #if the link leads to another wiki page
            go_to = "https://nds-nl.wikipedia.org" + url #save that link
#             print(url[6:])
            a_links.append(url[6:]) #link format /wiki/article, save the "article" name at the a_links list
                
matrix=[] #creates a zero content 2d matrix with the length and width of a_links list
for i in range(len(a_links)): 
    row=[] 
    for j in range(len(a_links)): 
        row.append(0) 
    matrix.append(row)
# Out:
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=463
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=463
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=De+Penne
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=De+Penne
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Drentse+schriefwieze
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Drentse+schriefwieze
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Englaand
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Englaand
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Gatbezen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Gatbezen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Grolle
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Grolle
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Heeten
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Heeten
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Huppel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Huppel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Jonen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Jonen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Kloepn
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Kloepn
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Lammert+Voos
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Lammert+Voos
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Luttenb%C3%A4rg
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Luttenb%C3%A4rg
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Mieuwen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Mieuwen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Nedersaksische+leedties
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Nedersaksische+leedties
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Nordic+walking
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Nordic+walking
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Opmeer
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Opmeer
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Pullepetaoters
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Pullepetaoters
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Russisk
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Russisk
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Skuppe
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Skuppe
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Streektaalpries
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Streektaalpries
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Tubbargn
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Tubbargn
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Verdan
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Verdan
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den

# %%
len(matrix)
# Out:
# 11077

# %%
flag = True #flag = true
dict = {}
i = 0
j = 0
k = len(a_links)
d = []
next_page = "https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen" #starting wikipedia page


flag = True #boolean
dict = {}

while flag: 

    res = requests.get(next_page)  #request page
#     print(res.text)
    soup = bs(res.text, "html.parser") #beautiful page constructor
    flag = False 
    for link in soup.find_all("a"): #finds all the "a" classes in the webpage

        url = link.get("href", "") #gets all the hyperlinks from the "a" class
        print(url)
        if "Volgende zied" in link.text.strip(): #if the link leads to the next page of all articles
            next_page = "https://nds-nl.wikipedia.org" + url #change the starting wikipedia page to the next one
            print (next_page)
            flag = True  #change flag to true
            continue 

        if url=='https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen': #if last page break
            break


        if "/wiki" in url: #if the link leads to another wiki page
            go_to = "https://nds-nl.wikipedia.org" + url #save that link
#             print(url[6:])
           
    #same as above till this line
            
#             print(go_to)
            res2 = requests.get(go_to) #requests each article's content
            soup2 = bs(res2.text, "html.parser") #bs constructor of each wikipedia article
            texts = soup2.find(class_="mw-parser-output") #finds the class of the main body of the article
#             print(texts)
            b_links.clear() 
            for links in texts.find_all('a'): #finds all the "a" classes in the article
                urls2 = links.get("href", "") #finds all the links from the "a" classes
                if "/wiki" in urls2: #if it leads to another wikipedia article
                    if not "redlink=1" in urls2: #ignores all links that lead to an article that does not exist
                        if not "action=edit" in urls2: #ignores all edit links of the article
                            if not "Bestaand" in urls2: #ignores all links that lead to a media file
                                if not ":" in urls2: #ignores all command links
                                    for j in range(0,k): #scans all the existing articles at a_links list
#                                         print (i)
#                                         print (j)
                                        if urls2[6:] == a_links[j]: #if the link name matches an existing name at that list
                                            matrix[i][j] = 1 #make that cell =1
            i = i + 1 #move to the next article
# Out:
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# /wiki/!REUR!
# /wiki/%22Ik_hete_IEKUS%22_%27n_keenderbook.
# /wiki/%25s
# /wiki/%27n_Ham
# /wiki/%27s-Eerenbroek
# /wiki/%27s-Heerenbarg
# /wiki/%27s-Hertogenbosch
# /wiki/%27s-Hertogenbosch_(gemeente)
# /wiki/%27s-Hertogenbosch_(stad)
# /wiki/%27t_Aol_Volk
# /wiki/%27t_Aol_Volk_Emmen
# /wiki/%27t_Attemerbroek
# /wiki/%27t_Grunneger_Bouk
# /wiki/%27t_Haantje
# /wiki/%27t_Harde
# /wiki/%27t_Hoogeveine
# /wiki/%27t_Huys_Dever
# /wiki/%27t_Klooster
# /wiki/%27t_Klooster_(Aalten)
# /wiki/%27t_Klooster_(Stienwiekerlaand)
# /wiki/%27t_Loo
# /wiki/%27t_Loo_(Oldebroek)
# /wiki/%27t_Ogeveine
# /wiki/%27t_Oogeveine
# /wiki/%27t_Oveine
# /wiki/%27t_Rieverst
# /wiki/%27t_Swieniegeltje
# /wiki/%27t_Veen
# /wiki/%27t_Vjenne
# /wiki/%27t_Walfort
# /wiki/%27t_Woud
# /wiki/%27t_Woud_(Niekark)
# /wiki/-um_(toponiemsuffix)
# /wiki/-wolde
# /wiki/0_(getal)
# /wiki/1
# /wiki/10
# /wiki/100
# /wiki/100_v._Chr.
# /wiki/101
# /wiki/102
# /wiki/103
# /wiki/104
# /wiki/105
# /wiki/106
# /wiki/107
# /wiki/108
# /wiki/109
# /wiki/10_april
# /wiki/10_augustus
# /wiki/10_december
# /wiki/10_desember
# /wiki/10_febrewaori
# /wiki/10_jannewaori
# /wiki/10_juli
# /wiki/10_juni
# /wiki/10_meert
# /wiki/10_mei
# /wiki/10_meie
# /wiki/10_november
# /wiki/10_oktober
# /wiki/10_september
# /wiki/10_v._Chr.
# /wiki/10e_eeuw
# /wiki/10e_eeuw_v._Chr.
# /wiki/10e_millennium_v._Chr.
# /wiki/11
# /wiki/110
# /wiki/111
# /wiki/112
# /wiki/113
# /wiki/114
# /wiki/115
# /wiki/116
# /wiki/117
# /wiki/1179
# /wiki/118
# /wiki/1185
# /wiki/1186
# /wiki/1187
# /wiki/1188
# /wiki/1189
# /wiki/119
# /wiki/1190
# /wiki/1191
# /wiki/1192
# /wiki/1193
# /wiki/1194
# /wiki/1195
# /wiki/1196
# /wiki/1197
# /wiki/1198
# /wiki/1199
# /wiki/11_april
# /wiki/11_augustus
# /wiki/11_december
# /wiki/11_desember
# /wiki/11_febrewaori
# /wiki/11_jannewaori
# /wiki/11_juli
# /wiki/11_juni
# /wiki/11_meert
# /wiki/11_mei
# /wiki/11_meie
# /wiki/11_november
# /wiki/11_oktober
# /wiki/11_september
# /wiki/11_v._Chr.
# /wiki/11e_eeuw
# /wiki/11e_ieuw
# /wiki/12
# /wiki/120
# /wiki/1200
# /wiki/121
# /wiki/122
# /wiki/1227
# /wiki/123
# /wiki/1233
# /wiki/1236
# /wiki/1237
# /wiki/124
# /wiki/1241
# /wiki/1243
# /wiki/1249
# /wiki/125
# /wiki/126
# /wiki/127
# /wiki/1277
# /wiki/128
# /wiki/129
# /wiki/12_april
# /wiki/12_augustus
# /wiki/12_december
# /wiki/12_desember
# /wiki/12_febrewaori
# /wiki/12_jannewaori
# /wiki/12_juli
# /wiki/12_juni
# /wiki/12_meert
# /wiki/12_mei
# /wiki/12_meie
# /wiki/12_november
# /wiki/12_oktober
# /wiki/12_september
# /wiki/12_v._Chr.
# /wiki/12e_eeuw
# /wiki/12e_ieuw
# /wiki/13
# /wiki/130
# /wiki/1301
# /wiki/1302
# /wiki/131
# /wiki/132
# /wiki/1326
# /wiki/133
# /wiki/134
# /wiki/1340
# /wiki/135
# /wiki/1350
# /wiki/1350-1359
# /wiki/136
# /wiki/1360
# /wiki/1360-1369
# /wiki/1361
# /wiki/1362
# /wiki/1363
# /wiki/1364
# /wiki/1365
# /wiki/1366
# /wiki/1367
# /wiki/1368
# /wiki/1369
# /wiki/137
# /wiki/1370
# /wiki/1370-1379
# /wiki/1371
# /wiki/1372
# /wiki/1373
# /wiki/1374
# /wiki/1375
# /wiki/1376
# /wiki/1377
# /wiki/1378
# /wiki/1379
# /wiki/138
# /wiki/1380
# /wiki/1380-1389
# /wiki/1381
# /wiki/1382
# /wiki/1383
# /wiki/1384
# /wiki/1385
# /wiki/1386
# /wiki/1387
# /wiki/1388
# /wiki/1389
# /wiki/139
# /wiki/1390
# /wiki/1390-1399
# /wiki/1391
# /wiki/1392
# /wiki/1393
# /wiki/1394
# /wiki/1395
# /wiki/1396
# /wiki/1397
# /wiki/1398
# /wiki/1399
# /wiki/13_april
# /wiki/13_augustus
# /wiki/13_december
# /wiki/13_desember
# /wiki/13_febrewaori
# /wiki/13_jannewaori
# /wiki/13_juli
# /wiki/13_juni
# /wiki/13_meert
# /wiki/13_mei
# /wiki/13_meie
# /wiki/13_november
# /wiki/13_oktober
# /wiki/13_september
# /wiki/13_v._Chr.
# /wiki/13e_eeuw
# /wiki/13e_ieuw
# /wiki/14
# /wiki/140
# /wiki/1400
# /wiki/1400-1409
# /wiki/1401
# /wiki/1402
# /wiki/1403
# /wiki/1404
# /wiki/1405
# /wiki/1406
# /wiki/1407
# /wiki/1408
# /wiki/1409
# /wiki/141
# /wiki/1410
# /wiki/1410-1419
# /wiki/1411
# /wiki/1412
# /wiki/1413
# /wiki/1414
# /wiki/1415
# /wiki/1416
# /wiki/1417
# /wiki/1418
# /wiki/1419
# /wiki/142
# /wiki/1420
# /wiki/1420-1429
# /wiki/1421
# /wiki/1422
# /wiki/1423
# /wiki/1424
# /wiki/1425
# /wiki/1426
# /wiki/1427
# /wiki/1428
# /wiki/1429
# /wiki/143
# /wiki/1430
# /wiki/1430-1439
# /wiki/1431
# /wiki/1432
# /wiki/1433
# /wiki/1434
# /wiki/1435
# /wiki/1436
# /wiki/1437
# /wiki/1438
# /wiki/1439
# /wiki/144
# /wiki/1440-1449
# /wiki/145
# /wiki/1450-1459
# /wiki/1451
# /wiki/1452
# /wiki/1456
# /wiki/146
# /wiki/147
# /wiki/1472
# /wiki/1475
# /wiki/148
# /wiki/1482
# /wiki/1487
# /wiki/149
# /wiki/1492
# /wiki/14_april
# /wiki/14_augustus
# /wiki/14_december
# /wiki/14_desember
# /wiki/14_febrewaori
# /wiki/14_jannewaori
# /wiki/14_juli
# /wiki/14_juni
# /wiki/14_meert
# /wiki/14_mei
# /wiki/14_meie
# /wiki/14_november
# /wiki/14_oktober
# /wiki/14_september
# /wiki/14_v._Chr.
# /wiki/14e_eeuw
# /wiki/14e_ieuw
# /wiki/15
# /wiki/150
# /wiki/1506
# /wiki/151
# /wiki/1519
# /wiki/152
# /wiki/1526
# /wiki/153
# /wiki/154
# /wiki/155
# /wiki/156
# /wiki/1562
# /wiki/1564
# /wiki/157
# /wiki/158
# /wiki/159
# /wiki/1591
# /wiki/1595
# /wiki/1597
# /wiki/15_april
# /wiki/15_augustus
# /wiki/15_december
# /wiki/15_desember
# /wiki/15_febrewaori
# /wiki/15_jannewaori
# /wiki/15_juli
# /wiki/15_juni
# /wiki/15_meert
# /wiki/15_mei
# /wiki/15_meie
# /wiki/15_november
# /wiki/15_oktober
# /wiki/15_september
# /wiki/15_v._Chr.
# /wiki/15e_eeuw
# /wiki/15e_ieuw
# /wiki/16
# /wiki/160
# /w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=%21REUR%21
# /w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# /wiki/1600
# /wiki/1605
# /wiki/1606
# /wiki/1609
# /wiki/161
# /wiki/1612
# /wiki/1615
# /wiki/1616
# /wiki/162
# /wiki/1621
# /wiki/1626
# /wiki/1627
# /wiki/163
# /wiki/1634
# /wiki/164
# /wiki/1644
# /wiki/1645
# /wiki/1646
# /wiki/165
# /wiki/1651
# /wiki/166
# /wiki/1669
# /wiki/167
# /wiki/1672
# /wiki/168
# /wiki/1685
# /wiki/169
# /wiki/1696
# /wiki/16_april
# /wiki/16_augustus
# /wiki/16_december
# /wiki/16_desember
# /wiki/16_febrewaori
# /wiki/16_jannewaori
# /wiki/16_juli
# /wiki/16_juni
# /wiki/16_meert
# /wiki/16_mei
# /wiki/16_meie
# /wiki/16_november
# /wiki/16_oktober
# /wiki/16_september
# /wiki/16_v._Chr.
# /wiki/16e_eeuw
# /wiki/17
# /wiki/170
# /wiki/1707
# /wiki/171
# /wiki/172
# /wiki/173
# /wiki/1736
# /wiki/174
# /wiki/1743
# /wiki/175
# /wiki/1750
# /wiki/1756
# /wiki/176
# /wiki/1765
# /wiki/1767
# /wiki/177
# /wiki/1770
# /wiki/1777
# /wiki/1778
# /wiki/178
# /wiki/1784
# /wiki/179
# /wiki/1791
# /wiki/1795
# /wiki/17_april
# /wiki/17_augustus
# /wiki/17_december
# /wiki/17_desember
# /wiki/17_febrewaori
# /wiki/17_februoari
# /wiki/17_jannewaori
# /wiki/17_januari
# /wiki/17_juli
# /wiki/17_juni
# /wiki/17_kesten_en_24_laandrechten
# /wiki/17_meert
# /wiki/17_mei
# /wiki/17_meie
# /wiki/17_november
# /wiki/17_oktober
# /wiki/17_september
# /wiki/17_v._Chr.
# /wiki/17e_eeuw
# /wiki/17e_ieuw
# /wiki/18
# /wiki/18._aiw
# /wiki/180
# /wiki/1803
# /wiki/1809
# /wiki/181
# /wiki/1810
# /wiki/1811
# /wiki/1813
# /wiki/1818
# /wiki/1819
# /wiki/182
# /wiki/1827
# /wiki/183
# /wiki/184
# /wiki/1840
# /wiki/1841
# /wiki/1842
# /wiki/1843
# /wiki/1844
# /wiki/185
# /wiki/1854
# /wiki/1856
# /wiki/186
# /wiki/1864
# /wiki/1867
# /wiki/1869
# /wiki/187
# /wiki/1870
# /wiki/1872
# /wiki/1873
# /wiki/1876
# /wiki/1879
# /wiki/188
# /wiki/1881
# /wiki/1882
# /wiki/1884
# /wiki/1885
# /wiki/1887
# /wiki/189
# /wiki/1894
# /wiki/1897
# /wiki/1899
# /wiki/18_april
# /wiki/18_augustus
# /wiki/18_december
# /wiki/18_desember
# /wiki/18_febrewaori
# /wiki/18_februari
# /wiki/18_jannewaori
# /wiki/18_juli
# /wiki/18_juni
# /wiki/18_meert
# /wiki/18_mei
# /wiki/18_meie
# /wiki/18_november
# /wiki/18_oktober
# /wiki/18_september
# /wiki/18_v._Chr.
# /wiki/18e_eeuw
# /wiki/18e_ieuw
# /wiki/19
# /wiki/19._aiw
# /wiki/190
# /wiki/1900
# /wiki/1901
# /wiki/1902
# /wiki/1903
# /wiki/1904
# /wiki/1906
# /wiki/1907
# /wiki/191
# /wiki/1910
# /wiki/1911
# /wiki/1918
# /wiki/1919
# /wiki/192
# /wiki/1920
# /wiki/1921
# /wiki/1926
# /wiki/1927
# /wiki/1929
# /wiki/193
# /wiki/1930
# /wiki/1932
# /wiki/1933
# /wiki/1935
# /wiki/1936
# /wiki/1938
# /wiki/1939
# /wiki/194
# /wiki/1940
# /wiki/1941
# /wiki/1942
# /wiki/1943
# /wiki/1944
# /wiki/1945
# /wiki/1946
# /wiki/1947
# /wiki/1948
# /wiki/1949
# /wiki/195
# /wiki/1950
# /wiki/1951
# /wiki/1952
# /wiki/1953
# /wiki/1954
# /wiki/1955
# /wiki/1956
# /wiki/1957
# /wiki/1958
# /wiki/1959
# /wiki/196
# /wiki/1960
# /wiki/1961
# /wiki/1962
# /wiki/1963
# /wiki/1964
# /wiki/1965
# /wiki/1966
# /wiki/1967
# /wiki/1968
# /wiki/1969
# /wiki/197
# /wiki/1970
# /wiki/1970-1979
# /wiki/1971
# /wiki/1972
# /wiki/1973
# /wiki/1974
# /wiki/1975
# /wiki/1976
# /wiki/1977
# /wiki/1978
# /wiki/1979
# /wiki/198
# /wiki/1980
# /wiki/1981
# /wiki/1982
# /wiki/1983
# /wiki/1984
# /wiki/1985
# /wiki/1986
# /wiki/1987
# /wiki/1988
# /wiki/1989
# /wiki/199
# /wiki/1990
# /wiki/1990-1999
# /wiki/1991
# /wiki/1992
# /wiki/1993
# /wiki/1994
# /wiki/1995
# /wiki/1996
# /wiki/1997
# /wiki/1998
# /wiki/1999
# /wiki/19_april
# /wiki/19_augustus
# /wiki/19_december
# /wiki/19_desember
# /wiki/19_febrewaori
# /wiki/19_februari
# /wiki/19_jannewaori
# /wiki/19_juli
# /wiki/19_juni
# /wiki/19_meert
# /wiki/19_mei
# /wiki/19_meie
# /wiki/19_november
# /wiki/19_oktober
# /wiki/19_september
# /wiki/19_v._Chr.
# /wiki/19e_eeuw
# /wiki/19e_ieuw
# /wiki/1_(getal)
# /wiki/1_april
# /wiki/1_augustus
# /wiki/1_december
# /wiki/1_desember
# /wiki/1_febrewaori
# /wiki/1_jannewaori
# /wiki/1_jannewaorie
# /wiki/1_jannewoari
# /wiki/1_januari
# /wiki/1_juli
# /wiki/1_juni
# /wiki/1_meert
# /wiki/1_mei
# /wiki/1_meie
# /wiki/1_november
# /wiki/1_oktober
# /wiki/1_september
# /wiki/1_v._Chr.
# /wiki/1e_eeuw
# /wiki/1e_eeuw_v._Chr.
# /wiki/2
# /wiki/20
# /wiki/20-miljoendreum
# /wiki/20-miljoendroom
# /wiki/20-miljoenendreum
# /wiki/20-miljoenendroom
# /wiki/20._aiw
# /wiki/200
# /wiki/2000
# /wiki/2001
# /wiki/2002
# /wiki/2003
# /wiki/2004
# /wiki/2005
# /wiki/2006
# /wiki/2007
# /wiki/2008
# /wiki/2009
# /wiki/201
# /wiki/2010
# /wiki/2011
# /wiki/2012
# /wiki/2013
# /wiki/2014
# /wiki/2015
# /wiki/2016
# /wiki/2017
# /wiki/2018
# /wiki/2019
# /wiki/202
# /wiki/2020
# /wiki/2021
# /wiki/2022
# /wiki/2023
# /wiki/2024
# /wiki/2025
# /wiki/2026
# /wiki/2027
# /wiki/2028
# /wiki/2029
# /wiki/203
# /wiki/2030
# /wiki/2031
# /wiki/2032
# /wiki/2033
# /wiki/2034
# /wiki/2035
# /wiki/2036
# /wiki/2037
# /wiki/2038
# /wiki/2039
# /wiki/204
# /wiki/2040
# /wiki/2041
# /wiki/2042
# /wiki/2043
# /wiki/2044
# /wiki/2045
# /wiki/2046
# /wiki/2047
# /w/index.php?title=Spesiaal:Alle_ziejen&from=%21REUR%21
# /w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# /w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# /wiki/2048
# /wiki/2049
# /wiki/205
# /wiki/2050
# /wiki/2051
# /wiki/2052
# /wiki/2053
# /wiki/2054
# /wiki/2055
# /wiki/2056
# /wiki/2057
# /wiki/2058
# /wiki/2059
# /wiki/206
# /wiki/2060
# /wiki/2061
# /wiki/2062
# /wiki/2063
# /wiki/2064
# /wiki/2065
# /wiki/2066
# /wiki/2067
# /wiki/2068
# /wiki/2069
# /wiki/207
# /wiki/2070
# /wiki/2071
# /wiki/2072
# /wiki/2073
# /wiki/2074
# /wiki/2075
# /wiki/2076
# /wiki/2077
# /wiki/2078
# /wiki/2079
# /wiki/208
# /wiki/2080
# /wiki/2081
# /wiki/2082
# /wiki/2083
# /wiki/2084
# /wiki/2085
# /wiki/2086
# /wiki/2087
# /wiki/2088
# /wiki/2089
# /wiki/209
# /wiki/2090
# /wiki/2091
# /wiki/2092
# /wiki/2093
# /wiki/2094
# /wiki/2095
# /wiki/2096
# /wiki/2097
# /wiki/2098
# /wiki/2099
# /wiki/20_april
# /wiki/20_augustus
# /wiki/20_december
# /wiki/20_desember
# /wiki/20_febrewaori
# /wiki/20_jannewaori
# /wiki/20_januari
# /wiki/20_juli
# /wiki/20_juni
# /wiki/20_meert
# /wiki/20_mei
# /wiki/20_meie
# /wiki/20_november
# /wiki/20_oktober
# /wiki/20_september
# /wiki/20_v._Chr.
# /wiki/20e_eeuw
# /wiki/20e_ieuw
# /wiki/21
# /wiki/210
# /wiki/2100
# /wiki/2101
# /wiki/2102
# /wiki/2103
# /wiki/2104
# /wiki/2105
# /wiki/2106
# /wiki/2107
# /wiki/2108
# /wiki/2109
# /wiki/211
# /wiki/2110
# /wiki/2111
# /wiki/2112
# /wiki/2113
# /wiki/2114
# /wiki/2115
# /wiki/2116
# /wiki/2117
# /wiki/2118
# /wiki/2119
# /wiki/212
# /wiki/2120
# /wiki/2121
# /wiki/2122
# /wiki/2123
# /wiki/2124
# /wiki/2125
# /wiki/2126
# /wiki/2127
# /wiki/2128
# /wiki/2129
# /wiki/213
# /wiki/2130
# /wiki/2131
# /wiki/2132
# /wiki/2133
# /wiki/2134
# /wiki/2135
# /wiki/2136
# /wiki/2137
# /wiki/2138
# /wiki/2139
# /wiki/214
# /wiki/2140
# /wiki/2141
# /wiki/2142
# /wiki/2143
# /wiki/2144
# /wiki/2145
# /wiki/2146
# /wiki/2147
# /wiki/2148
# /wiki/2149
# /wiki/215
# /wiki/2150
# /wiki/2151
# /wiki/2152
# /wiki/2153
# /wiki/2154
# /wiki/2155
# /wiki/2156
# /wiki/2157
# /wiki/2158
# /wiki/2159
# /wiki/216
# /wiki/2160
# /wiki/2161
# /wiki/2162
# /wiki/2163
# /wiki/2164
# /wiki/2165
# /wiki/2166
# /wiki/2167
# /wiki/2168
# /wiki/2169
# /wiki/217
# /wiki/2170
# /wiki/2171
# /wiki/2172
# /wiki/2173
# /wiki/2174
# /wiki/2175
# /wiki/2176
# /wiki/2177
# /wiki/2178
# /wiki/2179
# /wiki/218
# /wiki/2180
# /wiki/2181
# /wiki/2182
# /wiki/2183
# /wiki/2184
# /wiki/2185
# /wiki/2186
# /wiki/2187
# /wiki/2188
# /wiki/2189
# /wiki/219
# /wiki/2190
# /wiki/2191
# /wiki/2192
# /wiki/2193
# /wiki/2194
# /wiki/2195
# /wiki/2196
# /wiki/2197
# /wiki/2198
# /wiki/2199
# /wiki/21_april
# /wiki/21_augustus
# /wiki/21_december
# /wiki/21_desember
# /wiki/21_febrewaori
# /wiki/21_jannewaori
# /wiki/21_juli
# /wiki/21_juni
# /wiki/21_meert
# /wiki/21_mei
# /wiki/21_meie
# /wiki/21_november
# /wiki/21_oktober
# /wiki/21_september
# /wiki/21_v._Chr.
# /wiki/21e_eeuw
# /wiki/22
# /wiki/220
# /wiki/2200
# /wiki/2201
# /wiki/2202
# /wiki/2203
# /wiki/2204
# /wiki/2205
# /wiki/2206
# /wiki/2207
# /wiki/2208
# /wiki/2209
# /wiki/221
# /wiki/222
# /wiki/223
# /wiki/224
# /wiki/225
# /wiki/226
# /wiki/227
# /wiki/228
# /wiki/229
# /wiki/22_april
# /wiki/22_augustus
# /wiki/22_december
# /wiki/22_desember
# /wiki/22_febrewaori
# /wiki/22_jannewaori
# /wiki/22_juli
# /wiki/22_juni
# /wiki/22_meert
# /wiki/22_mei
# /wiki/22_meie
# /wiki/22_november
# /wiki/22_oktober
# /wiki/22_september
# /wiki/22_v._Chr.
# /wiki/22e_eeuw
# /wiki/23
# /wiki/230
# /wiki/231
# /wiki/232
# /wiki/233
# /wiki/234
# /wiki/235
# /wiki/236
# /wiki/237
# /wiki/238
# /wiki/239
# /wiki/23_april
# /wiki/23_augustus
# /wiki/23_december
# /wiki/23_desember
# /wiki/23_febrewaori
# /wiki/23_februari
# /wiki/23_jannewaori
# /wiki/23_jannewari
# /wiki/23_juli
# /wiki/23_juni
# /wiki/23_meert
# /wiki/23_mei
# /wiki/23_meie
# /wiki/23_november
# /wiki/23_oktober
# /wiki/23_september
# /wiki/23_v._Chr.
# /wiki/24
# /wiki/240
# /wiki/241
# /wiki/242
# /wiki/243
# /wiki/244
# /wiki/245
# /wiki/246
# /wiki/247
# /wiki/248
# /wiki/249
# /wiki/24_april
# /wiki/24_augustus
# /wiki/24_december
# /wiki/24_desember
# /wiki/24_febrewaori
# /wiki/24_februari
# /wiki/24_jannewaori
# /wiki/24_juli
# /wiki/24_juni
# /wiki/24_meert
# /wiki/24_mei
# /wiki/24_meie
# /wiki/24_november
# /wiki/24_oktober
# /wiki/24_september
# /wiki/24_v._Chr.
# /wiki/25
# /wiki/250
# /wiki/251
# /wiki/252
# /wiki/253
# /wiki/254
# /wiki/255
# /wiki/256
# /wiki/257
# /wiki/258
# /wiki/259
# /wiki/25_april
# /wiki/25_augustus
# /wiki/25_december
# /wiki/25_desember
# /wiki/25_febrewaori
# /wiki/25_jannewaori
# /wiki/25_juli
# /wiki/25_juni
# /wiki/25_meert
# /wiki/25_mei
# /wiki/25_meie
# /wiki/25_november
# /wiki/25_oktober
# /wiki/25_september
# /wiki/25_v._Chr.
# /wiki/26
# /wiki/260
# /wiki/261
# /wiki/262
# /wiki/263
# /wiki/264
# /wiki/265
# /wiki/266
# /wiki/267
# /wiki/268
# /wiki/269
# /wiki/26_april
# /wiki/26_augustus
# /wiki/26_december
# /wiki/26_desember
# /wiki/26_febrewaori
# /wiki/26_jannewaori
# /wiki/26_juli
# /wiki/26_juni
# /wiki/26_meert
# /wiki/26_mei
# /wiki/26_meie
# /wiki/26_november
# /wiki/26_oktober
# /wiki/26_september
# /w/index.php?title=Spesiaal:Alle_ziejen&from=1600
# /w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# /w/index.php?title=Spesiaal:Alle_ziejen&from=463
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=463
# /wiki/26_v._Chr.
# /wiki/27
# /wiki/270
# /wiki/271
# /wiki/272
# /wiki/273
# /wiki/274
# /wiki/275
# /wiki/276
# /wiki/277
# /wiki/278
# /wiki/279
# /wiki/27_april
# /wiki/27_augustus
# /wiki/27_december
# /wiki/27_desember
# /wiki/27_febrewaori
# /wiki/27_februari
# /wiki/27_jannewaori
# /wiki/27_juli
# /wiki/27_juni
# /wiki/27_meert
# /wiki/27_mei
# /wiki/27_meie
# /wiki/27_november
# /wiki/27_oktober
# /wiki/27_september
# /wiki/27_v._Chr.
# /wiki/28
# /wiki/280
# /wiki/281
# /wiki/282
# /wiki/283
# /wiki/284
# /wiki/285
# /wiki/286
# /wiki/287
# /wiki/288
# /wiki/289
# /wiki/28_april
# /wiki/28_augustus
# /wiki/28_december
# /wiki/28_desember
# /wiki/28_febrewaori
# /wiki/28_jannewaori
# /wiki/28_juli
# /wiki/28_juni
# /wiki/28_meert
# /wiki/28_mei
# /wiki/28_meie
# /wiki/28_november
# /wiki/28_oktober
# /wiki/28_september
# /wiki/28_v._Chr.
# /wiki/29
# /wiki/290
# /wiki/291
# /wiki/292
# /wiki/293
# /wiki/294
# /wiki/295
# /wiki/296
# /wiki/297
# /wiki/298
# /wiki/299
# /wiki/29_april
# /wiki/29_augustus
# /wiki/29_december
# /wiki/29_desember
# /wiki/29_febrewaori
# /wiki/29_jannewaori
# /wiki/29_januari
# /wiki/29_juli
# /wiki/29_juni
# /wiki/29_meert
# /wiki/29_mei
# /wiki/29_meie
# /wiki/29_november
# /wiki/29_oktober
# /wiki/29_september
# /wiki/29_v._Chr.
# /wiki/2_(getal)
# /wiki/2_april
# /wiki/2_augustus
# /wiki/2_december
# /wiki/2_desember
# /wiki/2_febrewaori
# /wiki/2_jannewaori
# /wiki/2_juli
# /wiki/2_juni
# /wiki/2_meert
# /wiki/2_mei
# /wiki/2_meie
# /wiki/2_november
# /wiki/2_oktober
# /wiki/2_september
# /wiki/2_v._Chr.
# /wiki/2e_eeuw
# /wiki/2e_eeuw_v._Chr.
# /wiki/3
# /wiki/30
# /wiki/300
# /wiki/301
# /wiki/302
# /wiki/303
# /wiki/304
# /wiki/305
# /wiki/306
# /wiki/307
# /wiki/308
# /wiki/309
# /wiki/30_Seconds_to_Mars
# /wiki/30_april
# /wiki/30_augustus
# /wiki/30_december
# /wiki/30_desember
# /wiki/30_febrewaori
# /wiki/30_jannewaori
# /wiki/30_januari
# /wiki/30_juli
# /wiki/30_juni
# /wiki/30_meart
# /wiki/30_meert
# /wiki/30_mei
# /wiki/30_meie
# /wiki/30_november
# /wiki/30_oktober
# /wiki/30_september
# /wiki/30_v._Chr.
# /wiki/31
# /wiki/310
# /wiki/311
# /wiki/312
# /wiki/313
# /wiki/314
# /wiki/315
# /wiki/316
# /wiki/317
# /wiki/318
# /wiki/319
# /wiki/31_augustus
# /wiki/31_december
# /wiki/31_desember
# /wiki/31_jannewaori
# /wiki/31_januari
# /wiki/31_juli
# /wiki/31_meert
# /wiki/31_mei
# /wiki/31_meie
# /wiki/31_oktober
# /wiki/31_v._Chr.
# /wiki/32
# /wiki/320
# /wiki/321
# /wiki/322
# /wiki/323
# /wiki/324
# /wiki/325
# /wiki/326
# /wiki/327
# /wiki/328
# /wiki/329
# /wiki/32_v._Chr.
# /wiki/33
# /wiki/330
# /wiki/331
# /wiki/332
# /wiki/333
# /wiki/334
# /wiki/335
# /wiki/336
# /wiki/337
# /wiki/338
# /wiki/339
# /wiki/33_v._Chr.
# /wiki/34
# /wiki/340
# /wiki/341
# /wiki/342
# /wiki/343
# /wiki/344
# /wiki/345
# /wiki/346
# /wiki/347
# /wiki/348
# /wiki/349
# /wiki/34_v._Chr.
# /wiki/35
# /wiki/350
# /wiki/351
# /wiki/352
# /wiki/353
# /wiki/354
# /wiki/355
# /wiki/356
# /wiki/357
# /wiki/358
# /wiki/359
# /wiki/35_v._Chr.
# /wiki/36
# /wiki/360
# /wiki/361
# /wiki/362
# /wiki/363
# /wiki/364
# /wiki/365
# /wiki/366
# /wiki/367
# /wiki/368
# /wiki/369
# /wiki/36_v._Chr.
# /wiki/37
# /wiki/370
# /wiki/371
# /wiki/372
# /wiki/373
# /wiki/374
# /wiki/375
# /wiki/376
# /wiki/377
# /wiki/378
# /wiki/379
# /wiki/37_v._Chr.
# /wiki/38
# /wiki/380
# /wiki/381
# /wiki/382
# /wiki/383
# /wiki/384
# /wiki/385
# /wiki/386
# /wiki/387
# /wiki/388
# /wiki/389
# /wiki/38_v._Chr.
# /wiki/39
# /wiki/390
# /wiki/391
# /wiki/392
# /wiki/393
# /wiki/394
# /wiki/395
# /wiki/396
# /wiki/397
# /wiki/398
# /wiki/399
# /wiki/39_v._Chr.
# /wiki/3FM
# /wiki/3FM_Serious_Request
# /wiki/3_april
# /wiki/3_augustus
# /wiki/3_december
# /wiki/3_desember
# /wiki/3_febrewaori
# /wiki/3_februari
# /wiki/3_jannewaori
# /wiki/3_januwoari
# /wiki/3_juli
# /wiki/3_juni
# /wiki/3_meert
# /wiki/3_mei
# /wiki/3_meie
# /wiki/3_november
# /wiki/3_oktober
# /wiki/3_september
# /wiki/3_v._Chr.
# /wiki/3e_eeuw
# /wiki/3e_eeuw_v._Chr.
# /wiki/4
# /wiki/40
# /wiki/400
# /wiki/401
# /wiki/402
# /wiki/403
# /wiki/404
# /wiki/405
# /wiki/406
# /wiki/407
# /wiki/408
# /wiki/409
# /wiki/40_v._Chr.
# /wiki/41
# /wiki/410
# /wiki/411
# /wiki/412
# /wiki/413
# /wiki/414
# /wiki/415
# /wiki/416
# /wiki/417
# /wiki/418
# /wiki/419
# /wiki/41_v._Chr.
# /wiki/42
# /wiki/420
# /wiki/421
# /wiki/422
# /wiki/423
# /wiki/424
# /wiki/425
# /wiki/426
# /wiki/427
# /wiki/428
# /wiki/429
# /wiki/42_v._Chr.
# /wiki/43
# /wiki/430
# /wiki/431
# /wiki/432
# /wiki/433
# /wiki/434
# /wiki/435
# /wiki/436
# /wiki/437
# /wiki/438
# /wiki/439
# /wiki/43_v._Chr.
# /wiki/44
# /wiki/440
# /wiki/441
# /wiki/442
# /wiki/443
# /wiki/444
# /wiki/445
# /wiki/446
# /wiki/447
# /wiki/448
# /wiki/449
# /wiki/44_v._Chr.
# /wiki/45
# /wiki/450
# /wiki/451
# /wiki/452
# /wiki/453
# /wiki/454
# /wiki/455
# /wiki/456
# /wiki/457
# /wiki/458
# /wiki/459
# /wiki/45_v._Chr.
# /wiki/46
# /wiki/460
# /wiki/461
# /wiki/462
# /w/index.php?title=Spesiaal:Alle_ziejen&from=2048
# /w/index.php?title=Spesiaal:Alle_ziejen&from=463
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=463
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# /w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# /wiki/463
# /wiki/464
# /wiki/465
# /wiki/466
# /wiki/467
# /wiki/468
# /wiki/469
# /wiki/46_v._Chr.
# /wiki/47
# /wiki/470
# /wiki/471
# /wiki/472
# /wiki/473
# /wiki/474
# /wiki/475
# /wiki/476
# /wiki/477
# /wiki/478
# /wiki/479
# /wiki/47_v._Chr.
# /wiki/48
# /wiki/480
# /wiki/481
# /wiki/482
# /wiki/483
# /wiki/484
# /wiki/485
# /wiki/486
# /wiki/487
# /wiki/488
# /wiki/489
# /wiki/48_v._Chr.
# /wiki/49
# /wiki/490
# /wiki/491
# /wiki/492
# /wiki/493
# /wiki/494
# /wiki/495
# /wiki/496
# /wiki/497
# /wiki/498
# /wiki/499
# /wiki/49_v._Chr.
# /wiki/4_april
# /wiki/4_augustus
# /wiki/4_december
# /wiki/4_desember
# /wiki/4_febrewaori
# /wiki/4_jannewaori
# /wiki/4_juli
# /wiki/4_juni
# /wiki/4_meert
# /wiki/4_mei
# /wiki/4_meie
# /wiki/4_november
# /wiki/4_oktober
# /wiki/4_september
# /wiki/4_v._Chr.
# /wiki/4e_eeuw
# /wiki/4e_eeuw_v._Chr.
# /wiki/5
# /wiki/50
# /wiki/500
# /wiki/501
# /wiki/502
# /wiki/503
# /wiki/504
# /wiki/505
# /wiki/506
# /wiki/507
# /wiki/508
# /wiki/509
# /wiki/50Plus
# /wiki/50_v._Chr.
# /wiki/51
# /wiki/510
# /wiki/511
# /wiki/512
# /wiki/513
# /wiki/514
# /wiki/515
# /wiki/516
# /wiki/517
# /wiki/518
# /wiki/519
# /wiki/51_v._Chr.
# /wiki/52
# /wiki/520
# /wiki/521
# /wiki/522
# /wiki/523
# /wiki/524
# /wiki/525
# /wiki/526
# /wiki/527
# /wiki/528
# /wiki/529
# /wiki/52_v._Chr.
# /wiki/53
# /wiki/530
# /wiki/531
# /wiki/532
# /wiki/533
# /wiki/534
# /wiki/535
# /wiki/536
# /wiki/537
# /wiki/538
# /wiki/539
# /wiki/53_v._Chr.
# /wiki/54
# /wiki/540
# /wiki/541
# /wiki/542
# /wiki/543
# /wiki/544
# /wiki/545
# /wiki/546
# /wiki/547
# /wiki/548
# /wiki/549
# /wiki/54_v._Chr.
# /wiki/55
# /wiki/550
# /wiki/551
# /wiki/55_v._Chr.
# /wiki/56
# /wiki/56_v._Chr.
# /wiki/57
# /wiki/57_v._Chr.
# /wiki/58
# /wiki/58_v._Chr.
# /wiki/59
# /wiki/59_v._Chr.
# /wiki/5_april
# /wiki/5_augustus
# /wiki/5_december
# /wiki/5_desember
# /wiki/5_febrewaori
# /wiki/5_jannewaori
# /wiki/5_juli
# /wiki/5_juni
# /wiki/5_meert
# /wiki/5_mei
# /wiki/5_meie
# /wiki/5_november
# /wiki/5_oktober
# /wiki/5_september
# /wiki/5_v._Chr.
# /wiki/5e_eeuw
# /wiki/5e_eeuw_v._Chr.
# /wiki/6
# /wiki/60
# /wiki/60_v._Chr.
# /wiki/61
# /wiki/61_v._Chr.
# /wiki/62
# /wiki/62_v._Chr.
# /wiki/63
# /wiki/63_v._Chr.
# /wiki/64
# /wiki/646
# /wiki/647
# /wiki/648
# /wiki/649
# /wiki/64_v._Chr.
# /wiki/65
# /wiki/650
# /wiki/651
# /wiki/652
# /wiki/653
# /wiki/654
# /wiki/655
# /wiki/656
# /wiki/657
# /wiki/658
# /wiki/659
# /wiki/65_v._Chr.
# /wiki/66
# /wiki/660
# /wiki/661
# /wiki/662
# /wiki/663
# /wiki/664
# /wiki/665
# /wiki/666
# /wiki/667
# /wiki/668
# /wiki/669
# /wiki/66_v._Chr.
# /wiki/67
# /wiki/670
# /wiki/671
# /wiki/672
# /wiki/673
# /wiki/674
# /wiki/675
# /wiki/67_v._Chr.
# /wiki/68
# /wiki/68_v._Chr.
# /wiki/69
# /wiki/69_v._Chr.
# /wiki/6_april
# /wiki/6_augustus
# /wiki/6_december
# /wiki/6_desember
# /wiki/6_febrewaori
# /wiki/6_februari
# /wiki/6_jannewaori
# /wiki/6_juli
# /wiki/6_juni
# /wiki/6_meert
# /wiki/6_mei
# /wiki/6_meie
# /wiki/6_november
# /wiki/6_oktober
# /wiki/6_september
# /wiki/6_v._Chr.
# /wiki/6e_eeuw
# /wiki/6e_eeuw_v._Chr.
# /wiki/7
# /wiki/70
# /wiki/70_v._Chr.
# /wiki/71
# /wiki/71_v._Chr.
# /wiki/72
# /wiki/72_v._Chr.
# /wiki/73
# /wiki/73_v._Chr.
# /wiki/74
# /wiki/74_v._Chr.
# /wiki/75
# /wiki/75_v._Chr.
# /wiki/76
# /wiki/76_v._Chr.
# /wiki/77
# /wiki/772
# /wiki/77_v._Chr.
# /wiki/78
# /wiki/78_v._Chr.
# /wiki/79
# /wiki/79_v._Chr.
# /wiki/7_april
# /wiki/7_augustus
# /wiki/7_december
# /wiki/7_desember
# /wiki/7_febrewaori
# /wiki/7_jannewaori
# /wiki/7_juli
# /wiki/7_juni
# /wiki/7_meert
# /wiki/7_mei
# /wiki/7_meie
# /wiki/7_november
# /wiki/7_oktober
# /wiki/7_september
# /wiki/7_v._Chr.
# /wiki/7e_eeuw
# /wiki/7e_eeuw_v._Chr.
# /wiki/8
# /wiki/80
# /wiki/80_v._Chr.
# /wiki/81
# /wiki/81_v._Chr.
# /wiki/82
# /wiki/82_v._Chr.
# /wiki/83
# /wiki/838
# /wiki/83_v._Chr.
# /wiki/84
# /wiki/843
# /wiki/84_v._Chr.
# /wiki/85
# /wiki/85_v._Chr.
# /wiki/86
# /wiki/86_v._Chr.
# /wiki/87
# /wiki/87_v._Chr.
# /wiki/88
# /wiki/88_v._Chr.
# /wiki/89
# /wiki/89_v._Chr.
# /wiki/8_april
# /wiki/8_augustus
# /wiki/8_december
# /wiki/8_desember
# /wiki/8_febrewaori
# /wiki/8_jannewaori
# /wiki/8_juli
# /wiki/8_juni
# /wiki/8_meert
# /wiki/8_mei
# /wiki/8_meie
# /wiki/8_november
# /wiki/8_oktober
# /wiki/8_september
# /wiki/8_v._Chr.
# /wiki/8e_eeuw
# /wiki/8e_eeuw_v._Chr.
# /wiki/8e_eeuwe
# /wiki/8e_ieuw
# /wiki/9
# /wiki/90
# /wiki/90_v._Chr.
# /wiki/91
# /wiki/91_v._Chr.
# /wiki/92
# /wiki/92_v._Chr.
# /wiki/93
# /wiki/93_v._Chr.
# /wiki/94
# /wiki/94_v._Chr.
# /wiki/95
# /wiki/95_v._Chr.
# /wiki/96
# /wiki/96_v._Chr.
# /wiki/97
# /wiki/972_v._Chr.
# /wiki/974_v._Chr.
# /wiki/97_v._Chr.
# /wiki/98
# /wiki/98_v._Chr.
# /wiki/99
# /wiki/99_v._Chr.
# /wiki/9_april
# /wiki/9_augustus
# /wiki/9_december
# /wiki/9_desember
# /wiki/9_febrewaori
# /wiki/9_jannewaori
# /wiki/9_juli
# /wiki/9_juni
# /wiki/9_meert
# /wiki/9_mei
# /wiki/9_meie
# /wiki/9_november
# /wiki/9_oktober
# /wiki/9_september
# /wiki/9_v._Chr.
# /wiki/9e_eeuw
# /wiki/9e_eeuw_v._Chr.
# /wiki/A.A._Steenbergen
# /wiki/A.C.W._Staring
# /wiki/A.L._Lesturgeon
# /w/index.php?title=Spesiaal:Alle_ziejen&from=26+v.+Chr.
# /w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=463
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# /wiki/A._A._Steenbergen
# /wiki/AKI_Artez
# /wiki/ANS
# /wiki/Aa-strang
# /wiki/Aa_en_Hunze
# /wiki/Aadorp
# /wiki/Aai
# /wiki/Aai_(toponiem)
# /wiki/Aaiber
# /wiki/Aaiberd
# /wiki/Aailaand
# /wiki/Aailaandsters
# /wiki/Aairlaand
# /wiki/Aalburg
# /wiki/Aalkruud
# /wiki/Aalsmeer
# /wiki/Aalt_Westerman
# /wiki/Aalten
# /wiki/Aalterpoorte
# /wiki/Aaltien_Kraak
# /wiki/Aaltien_kraak
# /wiki/Aambeeld
# /wiki/Aan_de_rand_van_Hollands_gouwen
# /wiki/Aanaarsamisk
# /wiki/Aardappel
# /wiki/Aarf
# /wiki/Aarften
# /wiki/Aarhus
# /wiki/Aarmelo
# /wiki/Aarteschuw
# /wiki/Aasters
# /wiki/Aauwerk
# /wiki/Aauwerk_(stad)
# /wiki/Abchazie
# /wiki/Abchazi%C3%AB
# /wiki/Abcoude
# /wiki/Abel_Darwinkel
# /wiki/Aberogwr
# /wiki/Achter-Drempt
# /wiki/Achter-Zuwwent
# /wiki/Achterhoek
# /wiki/Achterhoek_(Niekark)
# /wiki/Achterhoeks
# /wiki/Achterhoeks_woordenboek
# /wiki/Achterhook
# /wiki/Achterhook_(Hof_van_Tweante)
# /wiki/Achterhooks
# /wiki/Achterhooks_volkslied
# /wiki/Achterhooks_woordenbook
# /wiki/Achterhookse_warkwoorden
# /wiki/Achterhookse_zegswiezen
# /wiki/Achterhooksen_sproakgids
# /wiki/Achterhooksen_taalwiezer
# /wiki/Achtertune
# /wiki/Achterveld_(Barreveld)
# /wiki/Achterwael
# /wiki/Achterweal
# /wiki/Achtkarspelen
# /wiki/Acteur
# /wiki/Actrice
# /wiki/Adam-en-Eva
# /wiki/Adam-en-eva
# /wiki/Adam-en-eva_(Orchis_morio)
# /wiki/Adammetjes-en-evaatjes
# /wiki/Adderblad
# /wiki/Addervere
# /wiki/Addervere_(Polypodium)
# /wiki/Adel
# /wiki/Adige
# /wiki/Admiraliteit_van_Frieslaand
# /wiki/Adolf_Hitler
# /wiki/Adonai
# /wiki/Adriaan_Stoet
# /wiki/Adrianopel
# /wiki/Adriatiese_Zee
# /wiki/Adriatiesen_Zee
# /wiki/Adriatiesen_zee
# /wiki/Adriatische_Zee
# /wiki/Aefde
# /wiki/Aefsele
# /wiki/Aekinge
# /wiki/Aenesidemus
# /wiki/Aenske
# /wiki/Aeolische_%C3%B4fzetten
# /wiki/Aerde
# /wiki/Aeschines_Socraticus
# /wiki/Afganistan
# /wiki/Afghanistan
# /wiki/Afon_Garw
# /wiki/Afon_Llynfi
# /wiki/Afon_Ogwr
# /wiki/Afrika
# /wiki/Afrikaans
# /wiki/Afrikaans-Amerikaans
# /wiki/Afrikaans_Amerikaans
# /wiki/Afrikaansk
# /wiki/Afrikaon
# /wiki/Afrikaons
# /wiki/Afrike
# /wiki/Afrikoans
# /wiki/Afro-Amerikaan
# /wiki/Afro-Amerikaans
# /wiki/Afterbeat
# /wiki/Agnes_Frijlink
# /wiki/Agnez_Mo
# /wiki/Agnostisisme
# /wiki/Ahaus
# /wiki/Ahoes
# /wiki/Aiber
# /wiki/Aibert
# /wiki/Aider
# /wiki/Ajax
# /wiki/Ajax_Amsterdam
# /wiki/Akhenaten
# /wiki/Akkenailtje
# /wiki/Akkermannetje
# /wiki/Akkermannetjen
# /wiki/Akrotiri_en_Dhekelia
# /wiki/Aksent
# /wiki/Aksent_(radioprogramma)
# /wiki/Akteur
# /wiki/Aktiva
# /wiki/Aktrice
# /wiki/Alabama
# /wiki/Alabama_(duurverwiesziede)
# /wiki/Alabama_(stoat)
# /wiki/Aland
# /wiki/Alaska
# /wiki/Alaska_(stoat)
# /wiki/Alatri
# /wiki/Albani%C3%AB
# /wiki/Albeargn
# /wiki/Albergen
# /wiki/Albert_Aaldert_Metselaar
# /wiki/Albert_Dening
# /wiki/Albert_Einstein
# /wiki/Albert_Metselaar
# /wiki/Albert_Steenbergen
# /wiki/Albertus_Alidus_Steenbergen
# /wiki/Albertus_Christiaan_van_Raalte
# /wiki/Albertus_van_Raalte
# /wiki/Alblasserdam
# /wiki/Alborosie
# /wiki/Albraandsweard
# /wiki/Albraandsweerd
# /wiki/Albrandswaard
# /wiki/Aldeyjarfoss
# /wiki/Aletta_Jacobs
# /wiki/Alexander_Lodewijk_Lesturgeon
# /wiki/Alexander_Pechtold
# /wiki/Alexia_der_Nederlaanden
# /wiki/Alexia_van_Nederlaand
# /wiki/Alfen
# /wiki/Algemaine_Leegsaksiese_Schriefwieze
# /wiki/Algemaine_Leegsaksieze_Schriefwieze
# /wiki/Algemene_Intersassiske_Schryvwyse
# /wiki/Algemene_Nedersaksiese_Schriefwieze
# /wiki/Algemene_Nedersaksiese_Sjriefwieze
# /wiki/Algemene_Nedersaksiese_Skriefwieze
# /wiki/Algemene_Nedersaksiese_spelling
# /wiki/Algemene_Nedersaksische_Schriefwieze
# /wiki/Algemene_Nedersaksische_spelling
# /wiki/Algemeyne_Intersassiske_Skryvwyse
# /wiki/Algemeyne_Schryvwys%27
# /wiki/Algemiene_Nedersaksiese_Skreefweze
# /wiki/Algemiene_Nedersaksiese_Skriefwieze
# /wiki/Algerak
# /wiki/Ali_Brals-Luinge
# /wiki/Alkemade
# /wiki/Alkmaar
# /wiki/Alkmaar_(Nederlaand)
# /wiki/Allah
# /wiki/Allemannen
# /wiki/Allemannen_(volk)
# /wiki/Allennig
# /wiki/Allerheiligen
# /wiki/Allerselen
# /wiki/Allerzielen
# /wiki/Alles_Plat
# /wiki/Allesplat.nl
# /wiki/Alm
# /wiki/Almannaskar%C3%B0sg%C3%B6ng
# /wiki/Almelo
# /wiki/Almen
# /wiki/Almere
# /wiki/Alphen-Chaam
# /wiki/Alphen_an_de_Rien
# /wiki/Alphen_an_den_Rijn
# /wiki/Alphen_an_den_Rijn_(gemeente)
# /wiki/Also_sprach_Zarathustra
# /wiki/Alstae
# /wiki/Alstea
# /wiki/Aly_Freije
# /wiki/Amalia
# /wiki/Amalia_van_Nederlaand
# /wiki/Ambeeld
# /wiki/Ambeeld_(gereedschap)
# /wiki/Ambrogio_Spinola
# /wiki/Ambt_Dealdn
# /wiki/Ambthuus
# /wiki/Amelaand
# /wiki/Amelaand_(gemiente)
# /wiki/Amelaands
# /wiki/Amerika
# /wiki/Amerika_(kontinent)
# /wiki/Amersfoort
# /wiki/Amersfoort_(Zuud-Afrika)
# /wiki/Amersfoorts
# /wiki/Amesfoort
# /wiki/Amesfoorts
# /wiki/Amfibie%C3%ABn
# /wiki/Amstelveen
# /wiki/Amstelvene
# /wiki/Amsterdaam
# /wiki/Amsterdam
# /wiki/Amsterdams
# /wiki/Amsterdamsche_Veld
# /wiki/Amsterdamscheveld
# /wiki/Amsterdamscheveld_(Erica)
# /wiki/Amsterdamse_Skoele_(bouwstiel)
# /wiki/Amsven
# /wiki/An_de_Liende
# /wiki/Anarcho-primitivisme
# /wiki/Anarchoprimitivisme
# /wiki/Anchorage
# /wiki/Ancien_r%C3%A9gime
# /wiki/Andiek
# /wiki/Andievie
# /wiki/Andijk
# /wiki/Andorra
# /wiki/Andr%C3%A9_Manuel
# /wiki/Andr%C3%A9_van_Duin
# /wiki/Ane
# /wiki/Angelen
# /wiki/Angeln
# /wiki/Angelsaksen
# /wiki/Angelsassen
# /wiki/Angelus
# /wiki/Angelus_(gebed)
# /wiki/Anglesey
# /wiki/Anglo-Friese_talen
# /wiki/Anglo-Saxons
# /wiki/Anglo-freeske_spr%C3%A5ken
# /wiki/Anglosaksen
# /wiki/Angola
# /wiki/Anholt
# /wiki/Animisme
# /wiki/Ankh_Gussinklo
# /wiki/Ankleedtafel
# /wiki/Anna_Paulowna
# /wiki/Anna_Rita_Del_Piano
# /wiki/Anna_van_Saksen
# /wiki/Annales_regni_Francorum
# /wiki/Anne_Doornbos
# /wiki/Anne_Hoogebrug
# /wiki/Anne_van_der_Meiden
# /wiki/Anne_van_der_Meijden
# /wiki/Annie_Borckink
# /wiki/Annie_Schreijer-Pierik
# /wiki/Annije_Maria_Brans
# /wiki/Anthony_Christiaan_Winand_Staring
# /wiki/Antoniuskapel
# /wiki/Antropologie
# /wiki/Antwaarp
# /wiki/Antwaarp_(provinzie)
# /wiki/Antwaarp_(prov%C3%ACnzie)
# /wiki/Antwaarpen
# /wiki/Antwarpen
# /wiki/Antwerpen
# /wiki/Antwoordapperaot
# /wiki/Anubis
# /wiki/Anubis_(god)
# /wiki/Aofsluutdiek
# /wiki/Aojem
# /wiki/Aolburg
# /wiki/Aolkruud
# /wiki/Aolkruud_(Mentha_aquatica)
# /wiki/Aone
# /wiki/Aoveriessel
# /wiki/Apeldoorn
# /wiki/Apeldoorne
# /wiki/Apeldoorne_(gemeente)
# /wiki/Apeldoorne_(stad)
# /wiki/Aperloo
# /wiki/Apfelstrudel
# /wiki/Apokope
# /wiki/Apologisch_spreekwoord
# /wiki/Apostoliese_Vaars
# /wiki/Apostoliesen_Vaders
# /wiki/App
# /wiki/Appel
# /wiki/Appel_(Niekark)
# /wiki/Appel_(deurverwiespagina)
# /wiki/Appel_(vruch)
# /wiki/Appel_(vrucht)
# /wiki/Appelsche
# /wiki/Appelsien
# /wiki/Appelsmotse
# /wiki/Appen
# /wiki/Appen_(Nederland)
# /wiki/Appingedam
# /wiki/April
# /wiki/Arabies
# /wiki/Arabisch
# /wiki/Arabisk
# /wiki/Aramees
# /wiki/Arameesken
# /wiki/Arbeiders_Jeugd_Centrale
# /wiki/Arcen_en_Velden
# /wiki/Archemerbarg
# /wiki/Archeologie
# /wiki/Archimedes
# /wiki/Architectuur
# /wiki/Architektuur
# /wiki/Arem
# /wiki/Arend_ten_Oever
# /wiki/Arfgoodroute
# /wiki/Argentini%C3%AB
# /wiki/Ariane_der_Nederlaanden
# /wiki/Ariane_van_Nederlaand
# /wiki/Arianisme
# /wiki/Arie_Ribbers
# /wiki/Aristoteles
# /wiki/Arizona
# /wiki/Arizona_(duurverwiesziede)
# /wiki/Arizona_(stoat)
# /wiki/Arkansas
# /wiki/Arkansas_(duurverwiesziede)
# /wiki/Arkansas_(stoat)
# /wiki/Arkem
# /wiki/Arkemerbarg
# /wiki/Arktiese_Oseaan
# /wiki/Arktiesen_Oseaan
# /wiki/Armel
# /wiki/Armelo
# /wiki/Armelo_(deurverwieszied)
# /wiki/Armeloos
# /wiki/Armenie
# /wiki/Armeni%C3%AB
# /wiki/Armmarmottie
# /wiki/Arnem
# /wiki/Arnhem
# /wiki/Arnold_Rakers
# /wiki/Arnoldo_de_Ennethere
# /wiki/Arrow_Rock_Festival
# /w/index.php?title=Spesiaal:Alle_ziejen&from=463
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# /wiki/Artsach
# /wiki/Arve_Kots
# /wiki/Asgard
# /wiki/Asheldam
# /wiki/Asheldham
# /wiki/Ask_en_Embla
# /wiki/Askwoonsdag
# /wiki/Assel
# /wiki/Asselt
# /wiki/Assen
# /wiki/Assimilasie
# /wiki/Assimilasie_(Sproakleer)
# /wiki/Assimilasie_(sproakleer)
# /wiki/Asten
# /wiki/Astronomie
# /wiki/Atepoele
# /wiki/Atje_Keulen-Deelstra
# /wiki/Atlantiese_Oseaan
# /wiki/Atlantiesen_Oseaan
# /wiki/Atlantis
# /wiki/Atlantische_Oceaan
# /wiki/Atlantische_Ozeoan
# /wiki/Atlantisken_Oceaan
# /wiki/Attem
# /wiki/Attemerbroek
# /wiki/Attems
# /wiki/Attinsioa
# /wiki/Augustin_Wibbelt
# /wiki/Augustus
# /wiki/Augustus_Pablo
# /wiki/Aulk
# /wiki/Auste
# /wiki/Australi%27je
# /wiki/Australi%27je_(land)
# /wiki/Australi%C3%AB
# /wiki/Australi%C3%AB_(laand)
# /wiki/Australi%C3%AB_(land)
# /wiki/Austurland
# /wiki/Auteursrecht
# /wiki/Auto
# /wiki/Autorodeo
# /wiki/Auwerk
# /wiki/Avalon_(roman)
# /wiki/Avereest
# /wiki/Avereest_(gemiente)
# /wiki/Averiest
# /wiki/Averiest_(gemiente)
# /wiki/Avicii
# /wiki/Avvekaot
# /wiki/Avvekaot_(beroep)
# /wiki/Ayapa_Zoque
# /wiki/Azelo
# /wiki/Azem
# /wiki/Azerbaidjan
# /wiki/Azerbaidzjan
# /wiki/Azerbeidjan
# /wiki/Azerbeidzjan
# /wiki/Azie
# /wiki/Azien
# /wiki/Azi%C3%AB
# /wiki/Azoren
# /wiki/Azzen
# /wiki/BNN
# /wiki/BPM
# /wiki/BSR
# /wiki/Baand_(saamleaving)
# /wiki/Baark
# /wiki/Baarle-Nassau
# /wiki/Baarlo
# /wiki/Baarlo_(Stienwiekerlaand)
# /wiki/Baarm
# /wiki/Baarn
# /wiki/Baartman,_Nathalie
# /wiki/Baas_Boppe_Baas
# /wiki/Babberik
# /wiki/Babyboom
# /wiki/Babyboomer
# /wiki/Babyboomers
# /wiki/Bad
# /wiki/Bad_Beantem
# /wiki/Bad_Bentheim
# /wiki/Bad_Benthem
# /wiki/Bad_Beynthem
# /wiki/Bad_Doberan
# /wiki/Badde
# /wiki/Badding
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Badkupe
# /wiki/Baek_(Montferland)
# /wiki/Baek_(gemeente)
# /wiki/Baentiesman
# /wiki/Bagraain
# /wiki/Bahrein
# /wiki/Baiern
# /wiki/Baka
# /wiki/Bakhuus
# /wiki/Bakhuusbos
# /wiki/Bakkevene
# /wiki/Bakkiesman
# /wiki/Bakstiengotiek
# /wiki/Bakworst
# /wiki/Bakwos
# /wiki/Balejoarn
# /wiki/Balk_(Frieslaand)
# /wiki/Balkbrug
# /wiki/Balke
# /wiki/Balkenbri-j
# /wiki/Balkenbrij
# /wiki/Balkenende
# /wiki/Ballum
# /wiki/Baltiske_spr%C3%A5ken
# /wiki/Baltiske_talen
# /wiki/Band%27um
# /wiki/Band_(samenleaving)
# /wiki/Bandum
# /wiki/Banier
# /wiki/Banjo
# /wiki/Banke
# /wiki/Banke_(meubel)
# /wiki/Bante
# /wiki/Bantege
# /wiki/Bantem
# /wiki/Banthum
# /wiki/Baok
# /wiki/Baoren
# /wiki/Baorn
# /wiki/Baoven-Slinge
# /wiki/Barack_Obama
# /wiki/Barcelona
# /wiki/Barchem
# /wiki/Barendrecht
# /wiki/Bareveld
# /wiki/Barg_en_Dal_(Nederland)
# /wiki/Barg_en_Dal_(gemeente)
# /wiki/Barg_en_Delle_(Nederland)
# /wiki/Bargeijk
# /wiki/Bargen
# /wiki/Bargen_(Limburg)
# /wiki/Bargen_(Noord-Hollaand)
# /wiki/Bargen_(Noorwegen)
# /wiki/Bargen_op_Zoom
# /wiki/Bargente
# /wiki/Bargerveen
# /wiki/Bargervene
# /wiki/Bargeyk
# /wiki/Bargh
# /wiki/Barghuzen
# /wiki/Barghuzen_(Heerde)
# /wiki/Bargklooster
# /wiki/Bargske_kraier
# /wiki/Bargum
# /wiki/Bariton
# /wiki/Barkum
# /wiki/Barle
# /wiki/Barlo
# /wiki/Barnafoss
# /wiki/Barneveld
# /wiki/Barneveld_(daarp)
# /wiki/Barneveld_(gemeente)
# /wiki/Barnevelds_Woordenboek
# /wiki/Barok
# /wiki/Barreveld
# /wiki/Barreveld_(daarp)
# /wiki/Barreveld_(darp)
# /wiki/Barreveld_(gemeente)
# /wiki/Barrevelds
# /wiki/Basgitaar
# /wiki/Basiliek_van_Heilige_Ioannes_van_Lateranen
# /wiki/Basiliek_van_Sint-Jan_van_Lateranen
# /wiki/Baskies
# /wiki/Baskisk
# /wiki/Bassdrum
# /wiki/Basse
# /wiki/Basse_(Steenwiekerlaand)
# /wiki/Basse_(Stienwiekerlaand)
# /wiki/Basshunter
# /wiki/Bastion
# /wiki/Bat
# /wiki/Bataafse_Republiek
# /wiki/Bataafse_Rippebliek
# /wiki/Bataafse_revolutie
# /wiki/Bates_Motel
# /wiki/Bates_Motel_(televisysery)
# /wiki/Bathmen
# /wiki/Batoafse_Republiek
# /wiki/Batoafsen_Republeek
# /wiki/Batoafsen_revolusie
# /wiki/Bats
# /wiki/Batse
# /wiki/Batte
# /wiki/Battem
# /wiki/Batting
# /wiki/Bayern
# /wiki/Beak
# /wiki/Beak_(Montferland)
# /wiki/Beak_(gemeente)
# /wiki/Beak_(gemeente_Montferland)
# /wiki/Beakdoarp
# /wiki/Beake
# /wiki/Beantel
# /wiki/Beantem
# /wiki/Bearendina_Hertgers
# /wiki/Beatrix_der_Nederlaanden
# /wiki/Beatrix_der_Nederlanden
# /wiki/Beatrix_van_Nederlaand
# /wiki/Beats_Per_Minute
# /wiki/Beats_per_minute
# /wiki/Beckum
# /wiki/Bedde
# /wiki/Beddestee
# /wiki/Bedstee
# /wiki/Bedum
# /wiki/Bee_de_grote_watertoren
# /wiki/Beef
# /wiki/Beek
# /wiki/Beekbargen
# /wiki/Beeldende_keunst
# /wiki/Beeldende_kunst
# /wiki/Beem
# /wiki/Beemster
# /wiki/Beemte-Broekland
# /wiki/Beer
# /wiki/Beesel
# /wiki/Beestemark
# /wiki/Beetsterzwaog
# /wiki/Begraafplaatse_Bargklooster
# /wiki/Begraafplaatse_Bergklooster
# /wiki/Begrafenis
# /wiki/Begraffenis
# /wiki/Begreefplak
# /wiki/Behrns,_Johannes_Henricus
# /wiki/Beieren
# /wiki/Beiern
# /wiki/Beilen
# /wiki/Beinum
# /wiki/Bekbargen
# /wiki/Beke
# /wiki/Bekhof
# /wiki/Bekke
# /wiki/Bekkn_(meziekinstrumeant)
# /wiki/Bekn_(meziekinstrumeant)
# /wiki/Bekn_(muziekinstrumeant)
# /wiki/Bekveld
# /wiki/Belarus
# /wiki/Belcampo
# /wiki/Beleg
# /wiki/Beleg_van_Breevoort
# /wiki/Beleg_van_Breevoort_(1597)
# /wiki/Beleg_van_Breevoort_(1606)
# /wiki/Beleg_van_Breevoort_(1672)
# /wiki/Beleg_van_Grol
# /wiki/Beleg_van_Grol_(1595)
# /wiki/Beleg_van_Grol_(1627)
# /wiki/Belegeringe
# /wiki/Belfast
# /wiki/Belgie
# /wiki/Belgisch-Limburg
# /wiki/Belgi%C3%AB
# /wiki/Bellebloem
# /wiki/Bellenbloem
# /wiki/Bellever
# /wiki/Bels
# /wiki/Belstone
# /wiki/Belt-Schutsloot
# /wiki/Beltrum
# /wiki/Belvedere_Sch%C3%B6ne_H%C3%B6he
# /wiki/Ben_Feringa
# /wiki/Ben_Smits
# /wiki/Benedicta_Boccoli
# /wiki/Benedictus_XVI
# /wiki/Benin
# /wiki/Bennebroek
# /wiki/Bennebrook
# /wiki/Bennekom
# /wiki/Bennekum
# /wiki/Bennie_Jolink
# /wiki/Benrather_Linie
# /wiki/Benrather_linie
# /wiki/Bentelo
# /wiki/Bentemaoden
# /wiki/Benthem
# /wiki/Benul_bi%27j_eulifaanten
# /wiki/Berend_met_de_honden
# /wiki/Berendina_Hertgers
# /wiki/Berg_ane_Roer
# /wiki/Bergentheim
# /wiki/Bergklooster
# /wiki/Bergse_kraier
# /wiki/Bergveld-spelling
# /wiki/Beringstroat
# /wiki/Berkel
# /wiki/Berkellaand
# /wiki/Berkelland
# /wiki/Berkelzomp
# /wiki/Berkoop
# /wiki/Berkum
# /wiki/Berlewalde
# /wiki/Berlien
# /wiki/Berlyn
# /wiki/Bernard_van_Galen
# /wiki/Bernhard_van_Galen
# /wiki/Bernhard_von_Galen
# /wiki/Bernheze
# /wiki/Berre
# /wiki/Bert_Eeftink
# /wiki/Bert_Groothengel
# /wiki/Bert_van_de_Bunte
# /wiki/Bertha_Benz
# /wiki/Bertha_Vaags
# /wiki/Bertrand_Russell
# /wiki/Beschuut
# /wiki/Besjester
# /wiki/Beskuul
# /wiki/Besstee
# /wiki/Besthemerbarg
# /wiki/Bethlehem
# /wiki/Betlehem
# /wiki/Betlum
# /wiki/Betuwe
# /wiki/Betuws
# /wiki/Beukestad
# /wiki/Beulaeke
# /wiki/Beulake
# /wiki/Beune
# /wiki/Beuningen
# /wiki/Beuningen_(Gelderlaand)
# /wiki/Beusebarg
# /wiki/Beuseboarg
# /wiki/Beverwiek
# /wiki/Beverwijk
# /wiki/Bevolkensdichtte
# /wiki/Bevolking
# /wiki/Bevolkingsdichheid
# /wiki/Bevolkingsdichtheid
# /wiki/Bevolkingsdichthied
# /wiki/Beynthem
# /wiki/Bezemdopheed
# /wiki/Bezemheed
# /wiki/Bi%27j_de_grote_watertoren
# /wiki/Bi%27je
# /wiki/Bibliotheek
# /wiki/Biddinghuzen
# /wiki/Bie
# /wiki/Biebel
# /wiki/Biebel_(Grunnegers)
# /w/index.php?title=Spesiaal:Alle_ziejen&from=A.+A.+Steenbergen
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# /wiki/Biebel_(Grunnegs)
# /wiki/Biebel_in_de_Twentse_sproake
# /wiki/Biebelgordel
# /wiki/Biebelg%C3%B6rdel
# /wiki/Biebeltheek
# /wiki/Biedag
# /wiki/Biejen
# /wiki/Biejevreter
# /wiki/Biejn
# /wiki/Biekeuken
# /wiki/Bielefeld
# /wiki/Bieleveld
# /wiki/Bier
# /wiki/Bieslook
# /wiki/Biesteren
# /wiki/Bildts
# /wiki/Bilj%C3%A4rtn
# /wiki/Bimmen
# /wiki/Binnenalster
# /wiki/Binnenmaas
# /wiki/Binnenstad_(Eanske)
# /wiki/Binnenzee
# /wiki/Biologie
# /wiki/Birk
# /wiki/Biseksualiteait
# /wiki/Biseksualiteit
# /wiki/Biseksuoaliteait
# /wiki/Biskop
# /wiki/Bisschop
# /wiki/Bisschopsschaans
# /wiki/Bisschopsschaanze
# /wiki/Bisschopsweterink
# /wiki/Bissing
# /wiki/Bisskop
# /wiki/Bisskopsskaanze
# /wiki/Bjarnafoss
# /wiki/Blaauwe_Stad
# /wiki/Blaauwestad
# /wiki/Blaerteken
# /wiki/Blaker
# /wiki/Blankenham
# /wiki/Blaricum
# /wiki/Blauw_paapjen
# /wiki/Blauw_paapjen_(Parus_caeruleus)
# /wiki/Blauw_paapjen_(Prunella_modularis)
# /wiki/Blauwbloem
# /wiki/Blauwe_Bos
# /wiki/Blauwe_Gerrit
# /wiki/Blauwe_Haand
# /wiki/Blauwe_bees
# /wiki/Blauwe_beze
# /wiki/Blauwe_bosbeze
# /wiki/Blauwe_druufjes
# /wiki/Blauwe_gaai
# /wiki/Blauwehaand
# /wiki/Blauwen_Garrit
# /wiki/Blauwpaapjen
# /wiki/Blauwpaapjen_(Parus_caeruleus)
# /wiki/Blearteken
# /wiki/Blesdieke
# /wiki/Blesente
# /wiki/Bles%C3%A4nte
# /wiki/Bliende_slange
# /wiki/Blienzilver
# /wiki/Blikfluite
# /wiki/Bloaskapel
# /wiki/Bloedbleer
# /wiki/Bloedbleer_(bleer)
# /wiki/Bloeme
# /wiki/Bloemhof
# /wiki/Bloempot
# /wiki/Blokgooien
# /wiki/Blokziel
# /wiki/Blokzijl
# /wiki/Blomenkorso
# /wiki/Bloodm%C3%A5ne
# /wiki/Bloomendaal
# /wiki/Bloomendaal_(Noord-Hollaand)
# /wiki/Bloomenkorso
# /wiki/Blues
# /wiki/Boaden-Wurttembaarg
# /wiki/Boag
# /wiki/Boage
# /wiki/Boak
# /wiki/Boake
# /wiki/Boaken
# /wiki/Boarn
# /wiki/Boarne
# /wiki/Boarnebrook
# /wiki/Boaven-Slinge
# /wiki/Boavengraofschop
# /wiki/Bob_Marley
# /wiki/Bobby_McFerrin
# /wiki/Bocholt
# /wiki/Bocholter_Aa
# /wiki/Bochotnica
# /wiki/Bodbreef
# /wiki/Bodegraven
# /wiki/Bodegraven-Reeuwiek
# /wiki/Bodegrawen
# /wiki/Bodegrawen-Reewiek
# /wiki/Bodegroaven
# /wiki/Bodhran
# /wiki/Bodhr%C3%A1n
# /wiki/Body_Stress_Release
# /wiki/Boeddhisme
# /wiki/Boederi%27je
# /wiki/Boederieje
# /wiki/Boek
# /wiki/Boek_(anatomie)
# /wiki/Boek_(lichem)
# /wiki/Boek_(literetuur)
# /wiki/Boek_van_Mormon
# /wiki/Boeked
# /wiki/Boekel
# /wiki/Boekelte
# /wiki/Boekenbus
# /wiki/Boekenkaste
# /wiki/Boekenstad
# /wiki/Boeket
# /wiki/Boeket_(Fagopyrum_esculentum)
# /wiki/Boekhorst
# /wiki/Boekhost
# /wiki/Boekspieker
# /wiki/Boekweite
# /wiki/Boenen
# /wiki/Boengerd
# /wiki/Boer
# /wiki/Boerderi-je
# /wiki/Boerderie
# /wiki/Boerderiej
# /wiki/Boerderieje
# /wiki/Boerderije
# /wiki/Boerengolf
# /wiki/Boerenklokjen
# /wiki/Boerenrock
# /wiki/Boerenspil
# /wiki/Boerenwurmkruud
# /wiki/Boergondies
# /wiki/Boergondisch
# /wiki/Boergondisch_(tael)
# /wiki/Boerkabeljauw
# /wiki/Boern
# /wiki/Boernrock
# /wiki/Boerskop
# /wiki/Boertang
# /wiki/Boertanger_Moor
# /wiki/Boesenkool
# /wiki/Boeskool
# /wiki/Boeskooltrofee
# /wiki/Boetendiek
# /wiki/Boezenkool
# /wiki/Boh_Foi_Toch
# /wiki/Boh_foi_toch
# /wiki/Bohemen
# /wiki/Boi
# /wiki/Bokel
# /wiki/Bokel_(Eanske)
# /wiki/Bokel_(Hoksebarge)
# /wiki/Bokelerbekke
# /wiki/Bokelt
# /wiki/Bokking
# /wiki/Bokm%C3%A5l
# /wiki/Boksdoorne
# /wiki/Bokse
# /wiki/Boksebier
# /wiki/Boksempiep
# /wiki/Bolle
# /wiki/Bolnpeetr
# /wiki/Bolstoen
# /wiki/Bolsward
# /wiki/Bolwark
# /wiki/Bolwark_(stad)
# /wiki/Bommelerwaard
# /wiki/Bommelerweerd
# /wiki/Bommen_Berend
# /wiki/Bommenberend
# /wiki/Bondsrippebliek_Duutslaand
# /wiki/Bondsroad(Duutslaand)
# /wiki/Bondsroad_(Duutslaand)
# /wiki/Bontebok
# /wiki/Bontebok_(Frieslaand)
# /wiki/Bontebrug
# /wiki/Book_van_Mormon
# /wiki/Bookenstad
# /wiki/Bookestad
# /wiki/Bookmoal
# /wiki/Bookweaite
# /wiki/Bookweit
# /wiki/Bool
# /wiki/Boom_(deurverwiespagina)
# /wiki/Boomheed
# /wiki/Boorn
# /wiki/Boornerbrook
# /wiki/Boornse_Bek
# /wiki/Boornsterhem
# /wiki/Booschap
# /wiki/Booschap_(winkel)
# /wiki/Borculo
# /wiki/Bord
# /wiki/Borg
# /wiki/Borg_(Grunnen)
# /wiki/Borgemeister
# /wiki/Borger
# /wiki/Borgman
# /wiki/Boris_Johnson
# /wiki/Borkeld
# /wiki/Borken
# /wiki/Borkense_Baan
# /wiki/Borkense_Bane
# /wiki/Borklo
# /wiki/Borkulo
# /wiki/Borne
# /wiki/Bornerbroek
# /wiki/Borreltje
# /wiki/Borsele
# /wiki/Borsele_(gemeente)
# /wiki/Borsla-Pries
# /wiki/Borslapries
# /wiki/Borssele
# /wiki/Bos
# /wiki/Bosbarg
# /wiki/Bosbees
# /wiki/Bosbeze
# /wiki/Bosbezen
# /wiki/Boshoek
# /wiki/Boshoek_(Nederland)
# /wiki/Bosjaagr
# /wiki/Bosjager
# /wiki/Bosklopper_Gala
# /wiki/Bosni%C3%AB-Herzegovina
# /wiki/Bosni%C3%AB_en_Herzegovina
# /wiki/Boston
# /wiki/Boswachteri%27je_Stappest
# /wiki/Botniese_Golf
# /wiki/Botter
# /wiki/Bourgondisch
# /wiki/Bourtange
# /wiki/Bouwkeunst
# /wiki/Bouwkunst
# /wiki/Boven_Wotter
# /wiki/Boveneinde
# /wiki/Bovenveld
# /wiki/Bovenvene
# /wiki/Braandenb%C3%B6rg
# /wiki/Braandnetel
# /wiki/Braanze
# /wiki/Bram_Tankink
# /wiki/Brama,_Wout
# /wiki/Brammel
# /wiki/Brammelerbrook
# /wiki/Brammershoop
# /wiki/Brandenb%C3%B6rg
# /wiki/Branenburg
# /wiki/Braobaans
# /wiki/Braobaant
# /wiki/Braobaants
# /wiki/Braobans
# /wiki/Braobant
# /wiki/Braomp
# /wiki/Braompt
# /wiki/Brazielje
# /wiki/Brazili%C3%AB
# /wiki/Brazzaville
# /wiki/Breaking_Bad
# /wiki/Bred
# /wiki/Bred_(voat)
# /wiki/Bredevoort
# /wiki/Breedenbroek
# /wiki/Breedtegraod
# /wiki/Breedtegroad
# /wiki/Breekbonen
# /wiki/Breek%C3%B6rf
# /wiki/Breemn
# /wiki/Breenk
# /wiki/Breevoort
# /wiki/Bregje_Heinen
# /wiki/Breinigerberg
# /wiki/Brekebeen
# /wiki/Breking_(taol)
# /wiki/Brekkenpoolder
# /wiki/Brekking_(taal)
# /wiki/Breklenkaamp
# /wiki/Bremen
# /wiki/Bremen_(deurverwiespagina)
# /wiki/Bretagne
# /wiki/Bretanie
# /wiki/Bretanje
# /wiki/Bretanje_(strekke)
# /wiki/Breton
# /wiki/Bretons
# /wiki/Bretonsk
# /wiki/Breukelen
# /wiki/Breunishout
# /wiki/Brevenbusse
# /wiki/Brexit
# /wiki/Brian_O%27Nolan
# /wiki/Bridestowe
# /wiki/Brielle
# /wiki/Brink
# /wiki/Brinkdaarp
# /wiki/Brinkdarp
# /wiki/Brinkd%C3%B6rp
# /wiki/Brinkheurne
# /wiki/Brinkmanshoek
# /wiki/Brinkmanshook
# /wiki/Brion
# /wiki/Broabaants
# /wiki/Broabant
# /wiki/Broabants
# /wiki/Broampt
# /wiki/Brobargen
# /wiki/Broedlachte
# /wiki/Broek_(Brummen)
# /wiki/Broeke
# /wiki/Broeklaand_(Roalte)
# /wiki/Broenehaar
# /wiki/Broenswiek
# /wiki/Broenswiek_(stad)
# /wiki/Brog
# /wiki/Brogge
# /wiki/Brogge_(bouwwark)
# /wiki/Broke
# /wiki/Broken/Millingen_an_den_Rijn
# /wiki/Brokkebonen
# /wiki/Bromworm
# /wiki/Bronckhorst
# /wiki/Bronkhors
# /wiki/Bronkhorst
# /wiki/Bronstied
# /wiki/Brood
# /wiki/Brookheurnerbekke
# /wiki/Brouweri-je
# /wiki/Bructeren
# /wiki/Brug
# /wiki/Brugge
# /wiki/Brugge_(bouwwark)
# /wiki/Bruiloft
# /wiki/Bruker:Ptbotgourou
# /wiki/Brukjen
# /wiki/Brulfte
# /wiki/Brum
# /wiki/Brummel
# /wiki/Brummen
# /wiki/Brunssem
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Artsach
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Brunswiek
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Biebel+%28Grunnegs%29
# /w/index.php?title=Spesiaal:Alle_ziejen&from=De+Penne
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=De+Penne
# /wiki/Brunswiek
# /wiki/Brunswiek_(stad)
# /wiki/Brussel
# /wiki/Br%C3%B6mmel
# /wiki/Br%C3%BA
# /wiki/Budka_Suflera
# /wiki/Buil
# /wiki/Buiskooltrofee
# /wiki/Buizen_Beernd
# /wiki/Bukkem
# /wiki/Bukkes
# /wiki/Bulawayo
# /wiki/Bulgarije
# /wiki/Bulkalf
# /wiki/Bult,_Marga
# /wiki/Bunder
# /wiki/Bundesrat_(Duutslaand)
# /wiki/Bungels
# /wiki/Bunn
# /wiki/Bunnik
# /wiki/Bunschoten
# /wiki/Bunsjoots
# /wiki/Bunsjote
# /wiki/Bunsjoten
# /wiki/Bunzem
# /wiki/Bunzing
# /wiki/Buorken
# /wiki/Burcht
# /wiki/Buren
# /wiki/Buren_(Gelderlaand)
# /wiki/Burgemeister
# /wiki/Burgerlijkheid
# /wiki/Burgerlikheid
# /wiki/Burkina_Faso
# /wiki/Busekool
# /wiki/Bussloo
# /wiki/Bussloo_(plaatse)
# /wiki/Bussum
# /wiki/Butenalster
# /wiki/Butenplaatse
# /wiki/Butenpost
# /wiki/Buterheideveld
# /wiki/Butermeensken
# /wiki/Buttinge
# /wiki/Buuk
# /wiki/Buukspieker
# /wiki/Buurschop
# /wiki/Buurse
# /wiki/Buurtschap
# /wiki/Buurtschop
# /wiki/Buurtskop
# /wiki/Buussekool
# /wiki/Buutenplaetse
# /wiki/Byleveld
# /wiki/Byzantiense_Riek
# /wiki/B%C3%A5ke
# /wiki/B%C3%A8re
# /wiki/B%C3%B6aningen
# /wiki/B%C3%B6aningn
# /wiki/B%C3%B6kkers
# /wiki/B%C3%B6rg
# /wiki/B%C3%B6rge
# /wiki/B%C3%B6rger
# /wiki/B%C3%B6rger-Oring
# /wiki/B%C3%B6rk
# /wiki/B%C3%B6zzem
# /wiki/CDA
# /wiki/COVID-19
# /wiki/CSI
# /wiki/CSI_Tweante
# /wiki/CSI_Twente
# /wiki/Californi%C3%AB
# /wiki/Canada
# /wiki/Canarische_Eilanden
# /wiki/Cantabrische_Zee
# /wiki/Carnaval
# /wiki/Carolien_Hunneman
# /wiki/Carolus_Linnaeus
# /wiki/Cascada
# /wiki/Caselle_Landi
# /wiki/Caspar_David_Friedrich
# /wiki/Castellum
# /wiki/Castricum
# /wiki/Castrum
# /wiki/Catharina-Amalia_der_Nederlaanden
# /wiki/Catharina-Amalia_der_Nederlanden
# /wiki/Catharina-Amalia_van_Nederlaand
# /wiki/Catharina_Elderink
# /wiki/Cefet-MG
# /wiki/Cefet-RJ
# /wiki/Cefet/RJ
# /wiki/Cello
# /wiki/Celsius
# /wiki/Centraal-Afrikaanse_Republiek
# /wiki/Centraol-Europa
# /wiki/Centro_Federal_de_Educa%C3%A7%C3%A3o_Tecnol%C3%B3gica_Celso_Suckow_da_Fonseca
# /wiki/Centro_Federal_de_Educa%C3%A7%C3%A3o_Tecnol%C3%B3gica_de_Minas_Gerais
# /wiki/Cernunnos
# /wiki/Chamoaven
# /wiki/Champions_League
# /wiki/Champs-%C3%89lys%C3%A9es
# /wiki/Chan_Chan
# /wiki/Charles_Darwin
# /wiki/Chauken
# /wiki/Cherusken
# /wiki/Chicago
# /wiki/Chichen_Itza
# /wiki/Chili
# /wiki/Chillhop
# /wiki/Chimpansee
# /wiki/China
# /wiki/China_Walle
# /wiki/China_wall
# /wiki/China_walle
# /wiki/Chinees
# /wiki/Chineesk
# /wiki/Chinese_muur
# /wiki/Chocola
# /wiki/Christen-Democratisch_App%C3%A8l
# /wiki/Christendom
# /wiki/Christoffel_Columbus
# /wiki/Christoph_Bernhard_von_Galen
# /wiki/Christus
# /wiki/Cichorei
# /wiki/Circumvallatieliene
# /wiki/Circumvallatielinie
# /wiki/Citadel
# /wiki/Citadelle
# /wiki/Citroen
# ...
# /wiki/Wannepervene
# /wiki/Waogeningen
# /wiki/Waoiter
# /wiki/Waolenlaand
# /wiki/Waols
# /wiki/Waopen_van_Hoksebarge
# /wiki/Waopen_van_Losser
# /wiki/Waopen_van_Oldnzel
# /wiki/Waopen_van_Riesn-Hooltn
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Tubbargn
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Verdan
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# /wiki/Waopenvelde
# /wiki/Waopenvelde-Noord
# /wiki/Waore_Jezuskaark
# /wiki/Waore_Jezuskarke
# /wiki/Waore_Jezusk%C3%A4rke
# /wiki/Waoter
# /wiki/Waoterbotterbloeme
# /wiki/Waoterdamp
# /wiki/Waoterfoks
# /wiki/Waoterkiep
# /wiki/Waoterlelie
# /wiki/Waoterleliefemilie
# /wiki/Waotermunt
# /wiki/Waoterplaante
# /wiki/Waoterplaante_(algemeen)
# /wiki/Waoterplaanten
# /wiki/Waoterplaantjen
# /wiki/Waoterplantjen
# /wiki/Waotertoren_(Armelo)
# /wiki/Wapen_van_Eanske
# /wiki/Wapen_van_L%C3%B6nnker
# /wiki/Wapserveen
# /wiki/Wapservene
# /wiki/Warfstermeul
# /wiki/Warkhoven
# /wiki/Warkwoord
# /wiki/Warm_(Gelderland)
# /wiki/Warnduorp
# /wiki/Warnen
# /wiki/Warschau
# /wiki/Warsjau
# /wiki/Warven
# /wiki/Warvershoof
# /wiki/Wasbod
# /wiki/Wasbod_(boek)
# /wiki/Wasbod_(schoonmaek)
# /wiki/Washington
# /wiki/Washington_(stoat)
# /wiki/Waskemeer
# /wiki/Wasliende
# /wiki/Wassenaar
# /wiki/Wassenaer
# /wiki/Wat_Aans
# /wiki/Water
# /wiki/Waterburcht
# /wiki/Waterlaand_(gemeente)
# /wiki/Waterplat
# /wiki/Waterplatt
# /wiki/Waterschop
# /wiki/Waterstof
# /wiki/Wc
# /wiki/Wc-brille
# /wiki/Weal
# /wiki/Wealdarfgoodliest
# /wiki/Wealdarfgoodlieste
# /wiki/Wearkweurd
# /wiki/Wearldarvgoodlyste
# /wiki/Wearldsproake
# /wiki/Wearldspr%C3%A5ke
# /wiki/Weater
# /wiki/Weaveblad
# /wiki/Weaweblad
# /wiki/Webkroeper
# /wiki/Wedde-Bennewold
# /wiki/Weensum
# /wiki/Weenter
# /wiki/Weenterbaarg
# /wiki/Weenterboarg
# /wiki/Weerldarfgoedlieste
# /wiki/Weerlucht
# /wiki/Weersel
# /wiki/Weerselo
# /wiki/Weert
# /wiki/Weert_(gemeente)
# /wiki/Weerwoord
# /wiki/Weerwoord_(tiedschrift)
# /wiki/Weerwoord_(tiedskrift)
# /wiki/Wees
# /wiki/Wees-egroet
# /wiki/Weesp
# /wiki/Weite
# /wiki/Weitemanslaanden
# /wiki/Weke
# /wiki/Wekerom
# /wiki/Wekerum
# /wiki/Wekke
# /wiki/Wellerisme
# /wiki/Welsh
# /wiki/Wenen
# /wiki/Wenters
# /wiki/Wenterswiek
# /wiki/Wenum-Wiesel
# /wiki/Wenum_Wiesel
# /wiki/Weper
# /wiki/Weperbult
# /wiki/Weperpoolder
# /wiki/Wereldarfgoedlieste
# /wiki/Wereldarfgoodlieste
# /wiki/Werlddag_van_de_oceanen
# /wiki/Werner_(strip)
# /wiki/Wervelst%C3%B6rm
# /wiki/Wesent
# /wiki/Wespe
# /wiki/Wespen
# /wiki/Wessel
# /wiki/Wessel_(Barreveld)
# /wiki/Wessel_(naam)
# /wiki/Wessem
# /wiki/Wessinge
# /wiki/West-Afrika
# /wiki/West-Aoveriesselse_spelling
# /wiki/West-Duutslaand
# /wiki/West-Europa
# /wiki/West-Germaans
# /wiki/West-Germaanse_taal
# /wiki/West-Germaanse_taelen
# /wiki/West-Germaanse_talen
# /wiki/West-Germaanse_taolen
# /wiki/West-Germaanse_toalen
# /wiki/West-Germaonse_taolen
# /wiki/West-Germoans
# /wiki/West-Germoanse_toalen
# /wiki/West-Leegsaksisch
# /wiki/West-Maas_en_Waal
# /wiki/West-Meunsterlaands
# /wiki/West-Nedersaksisch
# /wiki/West-Oaveriesselse_spelling
# /wiki/West-Overiesselse_spelling
# /wiki/West-Overijsselse_spelling
# /wiki/West-Terschelling
# /wiki/West-Tweants
# /wiki/West-Veluws
# /wiki/West-Veluws_woordenboek
# /wiki/West-Virginia
# /wiki/West-Vlaams
# /wiki/West-Vlaanderen
# /wiki/West-Vlaoms
# /wiki/West-Vlaonderen
# /wiki/West-Vloams
# /wiki/West_Dart
# /wiki/West_Dart_River
# /wiki/West_Leegsaksisch
# /wiki/West_Leegsaksisch_(algemain)
# /wiki/West_Maas_en_Waal
# /wiki/West_Okement_River
# /wiki/West_Virginia
# /wiki/Westeinde_(Nunspeet)
# /wiki/Westendarp
# /wiki/Westendarp_(Epe)
# /wiki/Westendarp_(Olde_Iesselstreek)
# /wiki/Westeneng
# /wiki/Westerdaipsterdale
# /wiki/Westergo
# /wiki/Westerhaar
# /wiki/Westerhoevn
# /wiki/Westerkertaaier
# /wiki/Westerkertaaiers
# /wiki/Westerkertier
# /wiki/Westerkertiers
# /wiki/Westerketiers
# /wiki/Westerkwartaaier
# /wiki/Westerkwartaaiers
# /wiki/Westerkwartaar
# /wiki/Westerkwartaars
# /wiki/Westerlauwers_Fries
# /wiki/Westermeer
# /wiki/Westerschellings
# /wiki/Westerskellings
# /wiki/Westerveld
# /wiki/Westerveld_(gemiente)
# /wiki/Westervoort
# /wiki/Westerwolde
# /wiki/Westerwolds
# /wiki/Westerwoldse_Oa
# /wiki/Westerwoolde
# /wiki/Westerwoolde_(gemainte)
# /wiki/Westerwoolde_(streek)
# /wiki/Westerwoolds
# /wiki/Westerw%C3%B4lde
# /wiki/Westerw%C3%B4lds
# /wiki/Westfaals
# /wiki/Westfalen
# /wiki/Westfaolen
# /wiki/Westfaols
# /wiki/Westfeels
# /wiki/Westfele
# /wiki/Westflinge
# /wiki/Westfloandern
# /wiki/Westfoals
# /wiki/Westfrais
# /wiki/Westfreesk
# /wiki/Westfries
# /wiki/Westf%C3%A4%C3%B6lsk
# /wiki/Westf%C3%A5lsk
# /wiki/Westf%C3%B6%C3%A4lsk
# /wiki/Westhoekers
# /wiki/Westlaand
# /wiki/Westlaand_(gemeente)
# /wiki/Westlaauwers_Frais
# /wiki/Westland
# /wiki/Westm%C3%BCnsterlaands
# /wiki/Westnederduuts
# /wiki/Weststellingwarf
# /wiki/Westvlaandern
# /wiki/Westvoorne
# /wiki/Wetenschap
# /wiki/Wetenschop
# /wiki/Wetenskop
# /wiki/Wetering
# /wiki/Wetering_(Overiessel)
# /wiki/Weule
# /wiki/Weuste
# /wiki/Weuste_Hoeve
# /wiki/Wezep
# /wiki/Wichmond
# /wiki/Wicht
# /wiki/Widukind
# /wiki/Wieb
# /wiki/Wiechen
# /wiki/Wiedemeren
# /wiki/Wiedingharders
# /wiki/Wieje
# /wiki/Wiek_bi-j_Duurstede
# /wiki/Wiek_bi-j_Duurstee
# /wiki/Wiek_bie_Deurstea
# /wiki/Wiek_bie_Duurstede
# /wiki/Wiek_bie_Duurstee
# /wiki/Wieken_(Olde_Iesselstreek)
# /wiki/Wieken_(plaatse)
# /wiki/Wiel
# /wiki/Wielrennen
# /wiki/Wielrennen_(sport)
# /wiki/Wiemel
# /wiki/Wien
# /wiki/Wienbargen
# /wiki/Wienbargen_(Deutekem)
# /wiki/Wienbargen_(Epe)
# /wiki/Wiend
# /wiki/Wiendefamilie
# /wiki/Wiendefemilie
# /wiki/Wiendmeul
# /wiki/Wiendmeule
# /wiki/Wiendwiezer
# /wiki/Wiene
# /wiki/Wienen
# /wiki/Wienjewoolde
# /wiki/Wienter
# /wiki/Wierde
# /wiki/Wierde_(toponiem)
# /wiki/Wierden
# /wiki/Wierdn
# /wiki/Wieringen
# /wiki/Wieringermeer
# /wiki/Wiesneus
# /wiki/Wiet
# /wiki/Wietem
# /wiki/Wietkafee
# /wiki/Wietmarschen
# /wiki/Wietm%C3%B6rsken
# /wiki/Wijchen
# /wiki/Wijngaarden,_Willem_Jan_Christiaan_van
# /wiki/Wiki
# /wiki/Wikimedia_Foundation
# /wiki/Wikipedia
# /wiki/Wikipedie
# /wiki/Wikipedie:Praothoek
# /wiki/Wikipedie:Praotkefee
# /wiki/Wilde_karvel
# /wiki/Wilde_knovlouk
# /wiki/Wilde_ranker
# /wiki/Wilde_roze
# /wiki/Wilde_roze_(Rosa_canina)
# /wiki/Wilde_roze_(Rosa_eglanteria)
# /wiki/Wildenborch
# /wiki/Wildkunst
# /wiki/Wildleaven_kunst
# /wiki/Wilge
# /wiki/Wilgetee
# /wiki/Wilhelmine-Siefkes-Preis
# /wiki/Wilhelmine-Siefkes-Pries
# /wiki/Wilhelmus
# /wiki/Willem-Alexander_van_Nederlaand
# /wiki/Willem-Alexander_van_Oranje-Nassau
# /wiki/Willem-Alexander_van_de_Nedderlanden
# /wiki/Willem_Frederiks
# /wiki/Willem_Hendrik_Dingeldein
# /wiki/Willem_I
# /wiki/Willem_III
# /wiki/Willem_Jan_Christiaan_van_Wijngaarden
# /wiki/Willem_Kloeke
# /wiki/Willem_Seymour_Mulder
# /wiki/Willem_Terhorst
# /wiki/Willem_Tjebbe_Oostenbrink
# /wiki/Willem_V
# /wiki/Willem_Wilmink
# /wiki/Willem_van_Noesel
# /wiki/Willem_van_Oranje
# /wiki/Willemsoord
# /wiki/Willemsoord_(Steenwiekerlaand)
# /wiki/Willemsoord_(Stienwiekerlaand)
# /wiki/Willemstad
# /wiki/Willemstad_(Noord-Broabant)
# /wiki/Willemstad_(Ooststellingwarf)
# /wiki/Willewipper
# /wiki/William_Shakespeare
# /wiki/Willie_Oosterhuis
# /wiki/Willie_Oosterhuus
# /wiki/Willing
# /wiki/Wilm_van_Noesel
# /wiki/Wilm_van_Orannie
# /wiki/Wilmesauers
# /wiki/Wilmesaus
# /wiki/Wilmink,_Willem
# /wiki/Wilp
# /wiki/Wilp-Achterhoek
# /wiki/Wilsum
# /wiki/Wim_Plekkenpol
# /wiki/Wim_epskamp
# /wiki/Wim_plekkenpol
# /wiki/Wimme
# /wiki/Windesheim
# /wiki/Windesheim_(deurverwiespagina)
# /wiki/Windmeulen
# /wiki/Windm%C3%B6lle
# /wiki/Wingerd
# /wiki/Winkeldarp
# /wiki/Winkelshoek
# /wiki/Winkelshook
# /wiki/Winschoot
# /wiki/Winschoten
# /wiki/Winsum
# /wiki/Winter
# /wiki/Winter_Guard_International
# /wiki/Winterberg
# /wiki/Winterkeunings
# /wiki/Winterswiek
# /wiki/Winterswijk
# /wiki/Winzum
# /wiki/Winzum_(Grunnen)
# /wiki/Wisch
# /wiki/Wisconsin
# /wiki/Wisent
# /wiki/Wiskeunde
# /wiki/Wiskonsin_(stoat)
# /wiki/Wiskunde
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Verdan
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den
# /wiki/Wissel
# /wiki/Wissel_(Epe)
# /wiki/Wit-Roslaand
# /wiki/Wit-Ruslaand
# /wiki/Wit-Rusland
# /wiki/Wit_wief
# /wiki/Witmarsum
# /wiki/Witte_Peerden
# /wiki/Witte_wieve
# /wiki/Witte_wieven
# /wiki/Wittebrink
# /wiki/Wittekeend
# /wiki/Wittekind
# /wiki/Woalenlaand
# /wiki/Woals
# /wiki/Woapen_van_Eanske
# /wiki/Woapen_van_Hoksebarge
# /wiki/Woapen_van_Losser
# /wiki/Woapen_van_Loster
# /wiki/Woapen_van_L%C3%B6nnker
# /wiki/Woapen_van_Oldnzel
# /wiki/Woapen_van_Riesn-Hooltn
# /wiki/Woapen_van_de_Ommelanden
# /wiki/Woapen_van_eanske
# /wiki/Woar_de_noordseewellen
# /wiki/Woarskuwingsstelsel
# /wiki/Woater
# /wiki/Woaterburcht
# /wiki/Woaterlaand_(gemeente)
# /wiki/Woaterschop
# /wiki/Woaterskap
# /wiki/Woaterstof
# /wiki/Woaterv%C3%A4lle_in_Ieslaand
# /wiki/Wodan
# /wiki/Woden
# /wiki/Woening
# /wiki/Woenkamer
# /wiki/Woerden
# /wiki/Woeste_Hoeve
# /wiki/Wolbert
# /wiki/Woldfrais
# /wiki/Woldfries
# /wiki/Woldstad
# /wiki/Wolf
# /wiki/Wolfgang_Amadeus_Mozart
# /wiki/Wolvege
# /wiki/Wombaarg
# /wiki/Wommels
# /wiki/Wonderdadige_Medaille
# /wiki/Wonderdaodige_Medaille
# /wiki/Woold
# /wiki/Woold_(buurtschop)
# /wiki/Wooldbarg
# /wiki/Wooldfries
# /wiki/Wooldvucht
# /wiki/Woolters
# /wiki/Woonsdag
# /wiki/Woonserediel
# /wiki/Woordenboek_van_de_Achterhoekse_en_Liemerse_Dialecten
# /wiki/Woordenboek_van_de_Gelderse_Dialecten
# /wiki/Woordenboek_van_de_Overijsselse_Dialecten
# /wiki/Woordenboek_van_de_Overijsselse_Dialekten
# /wiki/Woordenbouken_Nedersaksisch
# /wiki/Workum
# /wiki/World_Geodetic_System
# /wiki/World_Geodetic_System_1984
# /wiki/World_Wide_Fund_for_Nature
# /wiki/Wormerlaand
# /wiki/Wotter
# /wiki/Woudenbarg
# /wiki/Woudrichem
# /wiki/Woudrichem_(gemeente)
# /wiki/Woudrichem_(veurmaolige_gemeente)
# /wiki/Wout_Brama
# /wiki/Wui
# /wiki/Wulf
# /wiki/Wulfenb%C3%BCddel
# /wiki/Wulv
# /wiki/Wurstfreesk
# /wiki/Wurstfries
# /wiki/Wye
# /wiki/Wymbritserediel
# /wiki/Wymbritserediel_(gemiente)
# /wiki/W%C3%A4ter
# /wiki/W%C3%B6lf
# /wiki/W%C3%B6rkem
# /wiki/YOLO
# /wiki/Yared_Dibaba
# /wiki/Yes_Tor
# /wiki/Yggdrasil
# /wiki/Ynys_M%C3%B4n
# /wiki/Yoghurt
# /wiki/Yolo
# /wiki/York_University
# /wiki/YouTube
# /wiki/You_Tube
# /wiki/Youtube
# /wiki/Ypelo
# /wiki/Yr_Wyddfa
# /wiki/Yrland
# /wiki/Yser
# /wiki/Ysland
# /wiki/Ysland-baskisk
# /wiki/Ysselakademy
# /wiki/Ysselakademy-spelling
# /wiki/ZO
# /wiki/ZOV
# /wiki/ZOZ
# /wiki/ZW
# /wiki/ZWD
# /wiki/ZWN
# /wiki/ZWZ
# /wiki/Zaand-Dr%C3%A8ents
# /wiki/Zaandhuzen
# /wiki/Zaandverstoeving
# /wiki/Zaandverstuving
# /wiki/Zaandvoort
# /wiki/Zaandzwelver
# /wiki/Zaank
# /wiki/Zaanstad
# /wiki/Zaender
# /wiki/Zaevender
# /wiki/Zais
# /wiki/Zakynthos
# /wiki/Zalk
# /wiki/Zalmachtigen
# /wiki/Zalt
# /wiki/Zalt_(smaak)
# /wiki/Zaltbommel
# /wiki/Zandbergen,_Jan
# /wiki/Zanger
# /wiki/Zangeres_van_zulver
# /wiki/Zangkeunst
# /wiki/Zaod
# /wiki/Zaod_(plaante)
# /wiki/Zaodplaanten
# /wiki/Zaoterdag
# /wiki/Zarathustra
# /wiki/Zeander
# /wiki/Zeander_(Oaveriessel)
# /wiki/Zeaspreuke
# /wiki/Zeaventien_Proveensien
# /wiki/Zeddam
# /wiki/Zederik
# /wiki/Zee
# /wiki/Zeek_(Olde_Iesselstreek)
# /wiki/Zeek_(plaatse)
# /wiki/Zeelaand
# /wiki/Zeespreuk
# /wiki/Zeespreuke
# /wiki/Zeespreuken
# /wiki/Zeeuws
# /wiki/Zeeuws-Vlaams_volkslied
# /wiki/Zeeuws-Vlaoms_volkslied
# /wiki/Zeeuws_volkslied
# /wiki/Zeevang
# /wiki/Zeewiefke
# /wiki/Zeewolde
# /wiki/Zeezwaoluw
# /wiki/Zeezwaoluwen
# /wiki/Zeispreuk
# /wiki/Zeispreuke
# /wiki/Zeist
# /wiki/Zekerheadsdeenst
# /wiki/Zeldam
# /wiki/Zelfkaant
# /wiki/Zelfkant
# /wiki/Zelhemse_Broek
# /wiki/Zellem
# /wiki/Zendamateur
# /wiki/Zerrem
# /wiki/Zeugdier
# /wiki/Zeugdiers
# /wiki/Zeum
# /wiki/Zeum_(Nunspeet)
# /wiki/Zeuning
# /wiki/Zeut
# /wiki/Zeute_Dr%C3%B6pkes
# /wiki/Zeutermear
# /wiki/Zeutermeer
# /wiki/Zeuterwolde
# /wiki/Zeuterwoolde
# /wiki/Zeuven_Fraise_Zeelanden
# /wiki/Zeuvenbuurt
# /wiki/Zeuvenhuzen
# /wiki/Zeuvenhuzen_(Bunsjoten)
# /wiki/Zeuvenhuzen_(Leek)
# /wiki/Zeuventien_Pervinsies
# /wiki/Zeuventien_Previnsien
# /wiki/Zeuvenwoolden
# /wiki/Zevenaar
# /wiki/Zielvest
# /wiki/Ziepe
# /wiki/Ziepe_(gemeente)
# /wiki/Ziepe_(reiniging)
# /wiki/Zierikzee
# /wiki/Zieuwent
# /wiki/Zijpe_(gemeente)
# /wiki/Zinnig
# /wiki/Zitroun_(vrucht)
# /wiki/Zoalt
# /wiki/Zoemer
# /wiki/Zoer
# /wiki/Zoer_(smaak)
# /wiki/Zoerbraand
# /wiki/Zoerik
# /wiki/Zoerlaand
# /wiki/Zoetermeer
# /wiki/Zoeterwoude
# /wiki/Zolt
# /wiki/Zolt_(smaak)
# /wiki/Zoltkamp
# /wiki/Zomer
# /wiki/Zommer
# /wiki/Zondaagse_kleare
# /wiki/Zonnebeek
# /wiki/Zoogdeer
# /wiki/Zoogdeers
# /wiki/Zoogdier
# /wiki/Zoogdieren
# /wiki/Zoogdiers
# /wiki/Zoolt
# /wiki/Zoomp
# /wiki/Zoompe
# /wiki/Zout
# /wiki/Zoutkamp
# /wiki/Zudelijk_halfroend
# /wiki/Zudelik_halfrond
# /wiki/Zuderdunen
# /wiki/Zuderzee
# /wiki/Zuderzeewarken
# /wiki/Zuid-Drents
# /wiki/Zuid_Eschmarke
# /wiki/Zuidhorn
# /wiki/Zuidplas
# /wiki/Zuidveen
# /wiki/Zuidwolde
# /wiki/Zujelijk_halfroend
# /wiki/Zujelijk_halfrond
# /wiki/Zujelik_halfroend
# /wiki/Zujelik_halfrond
# /wiki/Zujerzee
# /wiki/Zujerzeewarken
# /wiki/Zummer
# /wiki/Zundag
# /wiki/Zunne
# /wiki/Zunnebloeme
# /wiki/Zunneblomme
# /wiki/Zunnekoekeloeren
# /wiki/Zunnekuukn
# /wiki/Zunnestelsel
# /wiki/Zunnesysteem
# /wiki/Zunnewende
# /wiki/Zunnewende_(festival)
# /wiki/Zunnewende_Festival
# /wiki/Zunnewendefestival
# /wiki/Zunnewiezer
# /wiki/Zutfen
# /wiki/Zutfent
# /wiki/Zuthem
# /wiki/Zutphen
# /wiki/Zuud
# /wiki/Zuud-Afrika
# /wiki/Zuud-Afrikaans_Engels
# /wiki/Zuud-Carolina
# /wiki/Zuud-Drents
# /wiki/Zuud-Dr%C3%A8ents
# /wiki/Zuud-Europa
# /wiki/Zuud-Gelders
# /wiki/Zuud-Hollaand
# /wiki/Zuud-Hollaands_volkslied
# /wiki/Zuud-Hollaans
# /wiki/Zuud-Hollaans_volkslied
# /wiki/Zuud-Holland
# /wiki/Zuud-Jitlaand
# /wiki/Zuud-Jutlaand
# /wiki/Zuud-Jutland
# /wiki/Zuud-Jytlaand
# /wiki/Zuud-Korea
# /wiki/Zuud-Osseti%C3%AB
# /wiki/Zuud-Soedan
# /wiki/Zuud-Tirool
# /wiki/Zuud_Carolina
# /wiki/Zuud_Karolina
# /wiki/Zuud_Karolina_(stoat)
# /wiki/Zuudeinde
# /wiki/Zuudeinde_(Kampen)
# /wiki/Zuudende_(Steenwiekerlaand)
# /wiki/Zuudhorn
# /wiki/Zuudhouks
# /wiki/Zuudh%C3%B6rn
# /wiki/Zuudoost-Dr%C3%A8ents
# /wiki/Zuudoost-Veen-Dr%C3%A8ents
# /wiki/Zuudoost-Zaand-Dr%C3%A8ents
# /wiki/Zuudplas
# /wiki/Zuudsoedan
# /wiki/Zuudvene
# /wiki/Zuudvenegers
# /wiki/Zuudwest-Dr%C3%A8ents
# /wiki/Zuudwest-Frieslaand
# /wiki/Zuudwest-Noord-Dr%C3%A8ents
# /wiki/Zuudwest-Zuud-Dr%C3%A8ents
# /wiki/Zuudwesthoeks
# /wiki/Zuudwolde
# /wiki/Zuudwolde_(Drenthe)
# /wiki/Zuuk
# /wiki/Zwaonebloeme
# /wiki/Zwarte_Cross
# /wiki/Zwarte_Cross_Festival
# /wiki/Zwarte_Goor
# /wiki/Zwarte_Water
# /wiki/Zwarte_W%C3%A4ter
# /wiki/Zwarte_Zee
# /wiki/Zwartebroek
# /wiki/Zwartemeer
# /wiki/Zwarten_Piet
# /wiki/Zwartewaeterlaand
# /wiki/Zwartewaterklooster
# /wiki/Zwartewatersklooster
# /wiki/Zwartsluus
# /wiki/Zwatte_Zee
# /wiki/Zweden
# /wiki/Zweedn
# /wiki/Zweeds
# /wiki/Zwieg
# /wiki/Zwiendrecht
# /wiki/Zwiendrecht_(Nederlaand)
# /wiki/Zwientietikken
# /wiki/Zwiep
# /wiki/Zwijndrecht
# /wiki/Zwil
# /wiki/Zwilbrook
# /wiki/Zwitserlaand
# /wiki/Zwolle
# /wiki/Zwolle_(Gelderlaand)
# /wiki/Zwolle_(Oaveriessel)
# /wiki/Zwolle_(Oost_Gelre)
# /wiki/Zwolle_(deurverwiespagina)
# /wiki/Zwolle_(deurverwiesziede)
# /wiki/Zwols
# /wiki/Zwolse_synagoge
# /wiki/Zw%C3%A4rte_Meer
# /wiki/Zw%C3%A4rte_W%C3%A4ter
# /wiki/Zw%C3%A4rtew%C3%A4terklooster
# /wiki/Zw%C3%A4rtew%C3%A4terlaand
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Waopenvelde
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den
# https://nds-nl.wikipedia.org/w/index.php?title=Spesiaal:Alle_ziejen&from=Zw%C3%A8den
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen
#
# #mw-head
# #p-search
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# /wiki/Zw%C3%A8den
# /wiki/Zw%C3%B6ppe
# /wiki/Zw%C3%B6pslag
# /wiki/Zw%C3%B6pslag_in_n_nekke
# /wiki/Zyprus
# /wiki/Z%C3%A8lng
# /wiki/Z%C3%B6lfmoord
# /wiki/Z%C3%B6mmer
# /wiki/Z%C3%B6nnebekke
# /wiki/Z%C3%B6wwent
# /wiki/%C3%84%C3%A4rdv%C3%A4rken
# /wiki/%C3%85land
# /wiki/%C3%85landseilaanden
# /wiki/%C3%85landseilanen
# /wiki/%C3%85lkrai
# /wiki/%C3%85lkraie
# /wiki/%C3%85rhus
# /wiki/%C3%86%C3%B0arfossar
# /wiki/%C3%88%C3%A8fde
# /wiki/%C3%8Dr%C3%A1rfoss
# /wiki/%C3%8Ele_Amsterdam
# /wiki/%C3%8Eles_de_la_Madeleine
# /wiki/%C3%93f%C3%A6rufoss
# /wiki/%C3%96lfus%C3%A1
# /wiki/%C3%96lliekneppe
# /wiki/%C3%96ppervlakte
# /wiki/%C3%96rgel
# /wiki/%C3%96xar%C3%A1
# /wiki/%C3%96xar%C3%A1rfoss
# /wiki/%C3%96%C3%B6mrang
# /wiki/%C3%9Ej%C3%B3%C3%B0vegur_1
# /wiki/%C4%90%E1%BB%93ng_H%E1%BB%9Bi
# /wiki/%C5%81obez
# /wiki/%C5%9Awinouj%C5%9Bcie
# /wiki/%C5%9Ealom
# /wiki/%C5%A0iprage
# /wiki/%D0%A1%D1%80%D0%B1%D0%B8%D1%98%D0%B0
# /w/index.php?title=Spesiaal:Alle_ziejen&from=Wissel
# https://nds-nl.wikipedia.org/wiki/Spesiaal:Alle_ziejen

# %%
len(matrix)
# Out:
# 11077

# %%
import networkx as nx
G = nx.DiGraph() #graph constructor
for u in range(len(a_links)): #scan the matrix table
    G.add_node(a_links[u]) #add all strings from a_links table as nodes
    for v in range(len(a_links)):
        if matrix[u][v] == 1: #if the is a non zero cell
            G.add_edge(a_links[u],a_links[v]) #make an edge between the urls2 article and the correspondant a_lists article

# %%
G.number_of_edges()
# Out:
# 246389

# %%
nx.number_of_isolates(G)
# Out:
# 15

# %%
nx.density(G)
# Out:
# 0.0020082427700929177

# %%
list(nx.shortest_path(G, 'Alps', 'Aara'))
# Out:
# ['Alps', 'G%C3%BCglia', 'Aara']

# %%
nx.average_clustering(G)
# Out:
# 0.0

# %%
i = 100

print("Page:", a_links[i])
for j in range(len(matrix)):

    if matrix[i][j]==1: 
        print(j, a_links[j])
# Out:
# Page: 11_juni

# %%
import networkx as nx
MNIT = nx.Graph() #graph constructor
for u in range(len(a_links)): #scan the matrix table
    for v in range(len(a_links)):
        if matrix[u][v] == 1: #if the is a non zero cell
            MNIT.add_edge(a_links[u],a_links[v]) #make an edge between the urls2 article and the correspondant a_lists article
                
print(nx.average_shortest_path_length(MNIT))
# Out:
# 2.9629504313050665

# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx



degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)
ax.set_xlim(0,50)

plt.savefig('dutch1.png', dpi=300)

# %%
p = nx.clustering(G)

# %%
p = nx.clustering(G)
import operator
sorted_cluster_rm = sorted(p.items(), key = operator.itemgetter(1))
print(sorted_cluster_rm)
# Out:
# [('%27t_Loo', 0), ('Het_Geldersch_Landschap', 0), ('Vlagtwedde', 0), ('Woold', 0), ('0_(getal)', 0), ('Dirigent', 0), ('Vaar-en-moor-fietse', 0), ('Jacques_Fijn_van_Draat', 0), ('Gerrit_Wolsink', 0), ('Bert_Groothengel', 0), ('Daansmeziek', 0), ('2_(getal)', 0), ('Mubarak', 0), ('Ebola', 0), ('30_Seconds_to_Mars', 0), ('Daansmuziek', 0), ('Boston', 0), ('Aalkruud', 0), ('Aaltien_kraak', 0), ('Aambeeld', 0), ('Aan_de_rand_van_Hollands_gouwen', 0), ('Waarkwoord', 0), ('Armelo_(deurverwieszied)', 0), ('Aauwerk', 0), ('Actrice', 0), ('Aeolische_%C3%B4fzetten', 0), ('Eerdkern', 0), ('Umkeuperieje', 0), ('Oudheid', 0), ('Aktiva', 0), ('Auteursrecht', 0), ('Aktrice', 0), ('Alabama_(duurverwiesziede)', 0), ('Alatri', 0), ('Iersn_doedelzak', 0), ('The_Beatles', 0), ('Ambeeld', 0), ('Raaive', 0), ('Amsterdamsche_Veld', 0), ('Amsterdamscheveld', 0), ('Penne_(skriefgerei)', 0), ('Wees-egroet', 0), ('Antwaarp', 0), ('Antwaarpen', 0), ('Antwarpen', 0), ('Antwerpen', 0), ('Anubis', 0), ('Anubis_(god)', 0), ('Aolkruud', 0), ('Overijssels_Volkslied', 0), ('Apfelstrudel', 0), ('Appen', 0), ('Arizona_(duurverwiesziede)', 0), ('Arkansas_(duurverwiesziede)', 0), ('Arktiesen_Oseaan', 0), ('Ask_en_Embla', 0), ('Assimilasie', 0), ('Assimilasie_(Sproakleer)', 0), ('Assimilasie_(sproakleer)', 0), ('Australi%27je', 0), ('Australi%C3%AB', 0), ('Australi%C3%AB_(land)', 0), ('Avvekaot', 0), ('Ayapa_Zoque', 0), ('Yser', 0), ('BSR', 0), ('Katjen', 0), ('Baarlo', 0), ('Babyboom', 0), ('Babyboomers', 0), ('Bad', 0), ('Badde', 0), ('Dubai', 0), ('Baka', 0), ('Wealdarfgoodlieste', 0), ('Balke', 0), ('Balkenbri-j', 0), ('Banier', 0), ('Banke', 0), ('London', 0), ('Bargen', 0), ('Gaanze', 0), ('Barghuzen', 0), ('Letterkunde', 0), ('Bat', 0), ('Bates_Motel', 0), ('Spreng', 0), ('Beats_Per_Minute', 0), ('Beats_per_minute', 0), ('Beek', 0), ('Beleg_van_Breevoort', 0), ('Tongeren', 0), ('Benul_bi%27j_eulifaanten', 0), ('Bertha_Benz', 0), ('Besjester', 0), ('Beskuul', 0), ('Land', 0), ('Biebeltheek', 0), ('Biedag', 0), ('Verliefdheaid', 0), ('Blaerteken', 0), ('Blauw_paapjen', 0), ('Skuppe', 0), ('Blauwe_druufjes', 0), ('Blauwe_gaai', 0), ('Kuken', 0), ('Zaod', 0), ('Blauwpaapjen', 0), ('Blearteken', 0), ('Kiepe', 0), ('Blienzilver', 0), ('Bloedbleer', 0), ('Overpot', 0), ('Bloempot', 0), ('Bloodm%C3%A5ne', 0), ('Bloomendaal', 0), ('Niej-York_(deurverwiezing)', 0), ('Bochotnica', 0), ('Body_Stress_Release', 0), ('Boek', 0), ('Milt', 0), ('Boek_van_Mormon', 0), ('Geneeskunde', 0), ('Boekel', 0), ('Boeket', 0), ('Boekspieker', 0), ('Onderbokse', 0), ('Bontebok', 0), ('Book_van_Mormon', 0), ('Bool', 0), ('Verjaordag', 0), ('Boom_(deurverwiespagina)', 0), ('Booschap', 0), ('Bord', 0), ('Borssele', 0), ('Boshoek', 0), ('Ree', 0), ('Bourgondisch', 0), ('Hoef', 0), ('Braobaant', 0), ('Braobant', 0), ('Bred', 0), ('Bremen_(deurverwiespagina)', 0), ('Buren', 0), ('Broabant', 0), ('Broenswiek', 0), ('Bruker:Ptbotgourou', 0), ('Brunswiek', 0), ('Budka_Suflera', 0), ('Bungels', 0), ('Jager-verzamelders', 0), ('Buukspieker', 0), ('Klijndiek', 0), ('Canarische_Eilanden', 0), ('Caselle_Landi', 0), ('Chan_Chan', 0), ('Chichen_Itza', 0), ('Citadelle', 0), ('Citroen', 0), ('Pupe', 0), ('Raandstad', 0), ('Cola', 0), ('Colorado_(duurverwiesziede)', 0), ('Madonna', 0), ('Concepcion_(Stad,_Chili)', 0), ('Concepcion_(stad,_Chili)', 0), ('Connecticut_(duurverwiesziede)', 0), ('Parijs', 0), ('Cookie', 0), ('Moor', 0), ('Creative_Commons', 0), ('Kruud', 0), ('Vlearmoes', 0), ('Dans', 0), ('Heui', 0), ('Yes_Tor', 0), ('Harford', 0), ('De_Beek', 0), ('De_Driesprong', 0), ('De_Haar', 0), ('De_Haule', 0), ('De_Heurne', 0), ('De_Klomp', 0), ('Kiepkoare', 0), ('De_Leeuwte', 0), ('De_Meene', 0), ('De_Meene_(Hardenbarg)', 0), ('De_Penne', 0), ('De_Polle', 0), ('De_Stellingwarver_Schrieveri%27je_Pries', 0), ('Sams%C3%B8', 0), ('Dedemsvaart', 0), ('Dedemsvaort', 0), ('Delaware_(duurverwiesziede)', 0), ('Delaware_County', 0), ('Delden', 0), ('Depressie', 0), ('Luddevede', 0), ('Z%C3%B6lfmoord', 0), ('Deuv ...

# %%
c = nx.degree_centrality(G)
import operator
sorted_centrality_rm = sorted(c.items(), key = operator.itemgetter(1))
print(sorted_centrality_rm)
# Out:
# [('Blienzilver', 0.0), ('HDMI', 0.0), ('High-Definition_Multimedia_Interface', 0.0), ('High_Definition_Multimedia_Interface', 0.0), ('Hoe%3F_Zo!', 0.0), ('Infobox:Weg_in_Ieslaand', 0.0), ('Kontaktleans', 0.0), ('Pluto', 0.0), ('Schroeve', 0.0), ('Sollenpeper', 0.0), ('Vogelnoamen_Nederlands-Grunnegs', 0.0), ('V%C3%B6%C3%A4rblad_(ANS)', 0.0), ('Webkroeper', 0.0), ('Willem_V', 0.0), ('Zuud', 0.0), ('Aalkruud', 9.028530155290719e-05), ('Aambeeld', 9.028530155290719e-05), ('Aeolische_%C3%B4fzetten', 9.028530155290719e-05), ('Alatri', 9.028530155290719e-05), ('Ambeeld', 9.028530155290719e-05), ('Amsterdamsche_Veld', 9.028530155290719e-05), ('Amsterdamscheveld', 9.028530155290719e-05), ('Antwaarpen', 9.028530155290719e-05), ('Antwarpen', 9.028530155290719e-05), ('Anubis', 9.028530155290719e-05), ('Aolkruud', 9.028530155290719e-05), ('Ask_en_Embla', 9.028530155290719e-05), ('Assimilasie_(Sproakleer)', 9.028530155290719e-05), ('Assimilasie_(sproakleer)', 9.028530155290719e-05), ('Australi%27je', 9.028530155290719e-05), ('Avvekaot', 9.028530155290719e-05), ('Baarlo', 9.028530155290719e-05), ('Baka', 9.028530155290719e-05), ('Balke', 9.028530155290719e-05), ('Banke', 9.028530155290719e-05), ('Bat', 9.028530155290719e-05), ('Bates_Motel', 9.028530155290719e-05), ('Bertha_Benz', 9.028530155290719e-05), ('Beskuul', 9.028530155290719e-05), ('Blaerteken', 9.028530155290719e-05), ('Blearteken', 9.028530155290719e-05), ('Bloedbleer', 9.028530155290719e-05), ('Bloempot', 9.028530155290719e-05), ('Bloomendaal', 9.028530155290719e-05), ('Boeket', 9.028530155290719e-05), ('Bontebok', 9.028530155290719e-05), ('Boom_(deurverwiespagina)', 9.028530155290719e-05), ('Bourgondisch', 9.028530155290719e-05), ('Bremen_(deurverwiespagina)', 9.028530155290719e-05), ('Bruker:Ptbotgourou', 9.028530155290719e-05), ('Buukspieker', 9.028530155290719e-05), ('Caselle_Landi', 9.028530155290719e-05), ('Creative_Commons', 9.028530155290719e-05), ('De_Driesprong', 9.028530155290719e-05), ('De_Haar', 9.028530155290719e-05), ('De_Haule', 9.028530155290719e-05), ('De_Leeuwte', 9.028530155290719e-05), ('De_Penne', 9.028530155290719e-05), ('De_Polle', 9.028530155290719e-05), ('Delaware_County', 9.028530155290719e-05), ('Depressie', 9.028530155290719e-05), ('Doebai', 9.028530155290719e-05), ('Dorset', 9.028530155290719e-05), ('Drumpel', 9.028530155290719e-05), ('Eschweiler', 9.028530155290719e-05), ('Femilie', 9.028530155290719e-05), ('Filips_II', 9.028530155290719e-05), ('Gallerieje', 9.028530155290719e-05), ('Gemeante', 9.028530155290719e-05), ('Gemeeinte', 9.028530155290719e-05), ('Geografische_ko%C3%B6rdinaoten', 9.028530155290719e-05), ('Geografische_ko%C3%B6rdinaten', 9.028530155290719e-05), ('Poldernederlaands', 9.028530155290719e-05), ('Grezzelet', 9.028530155290719e-05), ('Grunny', 9.028530155290719e-05), ('Gunees_Keuntjen', 9.028530155290719e-05), ('Gunees_keuntjen', 9.028530155290719e-05), ('Haart', 9.028530155290719e-05), ('Willem_III', 9.028530155290719e-05), ('Haonepoot', 9.028530155290719e-05), ('Haren', 9.028530155290719e-05), ('Hartogdomme', 9.028530155290719e-05), ('Haule', 9.028530155290719e-05), ('Heemstede', 9.028530155290719e-05), ('Heern', 9.028530155290719e-05), ('Herik', 9.028530155290719e-05), ('Hering', 9.028530155290719e-05), ('Het', 9.028530155290719e-05), ('Hieronymus', 9.028530155290719e-05), ('Hulk', 9.028530155290719e-05), ('Indo-Europese_rilligie', 9.028530155290719e-05), ('Jaap_Meijer', 9.028530155290719e-05), ('Jajem', 9.028530155290719e-05), ('Jonen', 9.028530155290719e-05), ('Karen', 9.028530155290719e-05), ('Keuning', 9.028530155290719e-05), ('Klark', 9.028530155290719e-05), ('Klosse', 9.028530155290719e-05), ('Kluus', 9.028530155290719e-05), ('Knien', 9.028530155290719e-05), ('Kniende', 9.028530155290719e-05), ('Koaperbreef', 9.028530155290719e-05), ('Kouwe', 9.028530155290719e-05), ('Kranenburg', 9.028530155290719e-05), ('Kreool', 9.028530155290719e-05), ('K%C3%A5rel_de_Groute', 9.028530155290719e-05), ('K%C3%B6nning', 9.02853015529071 ...

# %%
nx.average_clustering(G)
# Out:
# 0.24308896609864886

# %%
list(nx.all_neighbors(G,'Europa'))
# Out:
# ['19avel_tschientaner',
#  '20avel_tschientaner',
#  'Absolutissem',
#  'Agricultura',
#  'Albania',
#  'Aliz%C3%A9e',
#  'Alps',
#  'America_dal_Nord',
#  'Amnesty_International',
#  'Amsterdam',
#  'Andorra',
#  'Andorra_la_Vella',
#  'Antica',
#  'Archeologia',
#  'Associaziun_europeica_da_commerzi_liber',
#  'Athen',
#  'Austria',
#  'Aviez',
#  'Badugn_pendus',
#  'Ballamaun',
#  'Ballarait',
#  'Basel',
#  'Basilea',
#  'Basileia',
#  'Belgia',
#  'Belgrad',
#  'Berlin',
#  'Bern',
#  'Berna',
#  'Bielorussia',
#  'Bosnia-Erzegovina',
#  'Bosnia_ed_Erzegovina',
#  'Bratislava',
#  'Breton',
#  'Broken/Reginavel_un%C3%AC_da_la_Gronda_Britannia_ed_Irlanda_dal_Nord',
#  'Brussel',
#  'Brutg',
#  'Bruxelles',
#  'Br%C3%BCssel',
#  'Bucarest',
#  'Bucaresta',
#  'Bucuresti',
#  'Bucure%C5%9Fti',
#  'Bucure%C8%99ti',
#  'Budapest',
#  'Budissem',
#  'Bukarest',
#  'Bulgaria',
#  'Canis_familiaris',
#  'Canis_lupus_familiaris',
#  'Casachstan',
#  'Castur',
#  'Catastrofa_nucleara_da_Fukushima',
#  'Celts',
#  'Celts_(sursilvan)',
#  'Charpin',
#  'Chaun',
#  'Chaval',
#  'Chisinau',
#  'Chi%C5%9Fin%C4%83u',
#  'Chi%C8%99in%C4%83u',
#  'Cipra',
#  'Citad_da_San_Marino',
#  'Citad_dal_Vatican',
#  'Clavazin',
#  'Colonialissem',
#  'Commerzi_da_sclavs',
#  'Communissem',
#  'Conservatissem',
#  'Continent',
#  'Copenhagen',
#  'Cosovo',
#  'Crisa_economica_mundiala',
#  'Cristianissem',
#  'Cristof_Columbus',
#  'Croazia',
#  'Culaischen',
#  'Cumpostar',
#  'Cuntrarefurma',
#  'Cuntrarefurmaziun',
#  'DJ_BoBo',
#  'Dafna',
#  'Danemarc',
#  'Danubi',
#  'Democrazia',
#  'Dretgs_umans',
#  'Dublin',
#  'Dumonda_sociala',
#  'Economia_mundiala',
#  'Emprema_Uiara_mundiala',
#  'Emprima_Guerra_mundiala',
#  'Energia_termosolara',
#  'Epoca_da_las_revoluziuns',
#  'Equus_caballus',
#  'Equus_ferus_caballus',
#  'Estonia',
#  'Europa_Centrala',
#  'Faschissem',
#  'Fau_verd',
#  'Federalissem',
#  'Federaziun_Russa',
#  'Finanzas_publicas',
#  'Finlanda',
#  'Flum',
#  'Flur-portg',
#  'Fond_monetar_internaziunal',
#  'Formicidae',
#  'Fraissen_cumin',
#  'Frantscha',
#  'Furmicla',
#  'Furmiclas',
#  'Furmla_1',
#  'Germania',
#  'Giansauna_senza_moni',
#  'Ginaiver_cumin',
#  'GiuRu',
#  'Giudaissem',
#  'Giura_(chadaina)',
#  'Giuru',
#  'Giuventetgna_Rumantscha',
#  'Globalisaziun',
#  'Greenpeace',
#  'Grezia',
#  'Guaud',
#  'Guerra_civila_spagnola',
#  'Guerra_da_trent%27onns',
#  'Haddaway',
#  'Hamburg',
#  'Hellas',
#  'Helsinki',
#  'Henri_Guisan',
#  'Holland',
#  'Holocaust',
#  'Il_baroc_en_terra_rumantscha',
#  'Illuminissem',
#  'Imperi_roman',
#  'Imperi_romaun',
#  'Imperialissem',
#  'Intensitad_(terratrembel)',
#  'Irlanda_dal_Nord',
#  'Ischi_champester',
#  'Ischi_da_muntogna',
#  'Ischi_giz',
#  'Islanda',
#  'Istorgia_da_l%27Europa',
#  'Istorgia_da_l%27umanitad',
#  'Istorgia_da_la_posta',
#  'Istorgia_da_la_telecommunicaziun',
#  'Istorgia_da_la_viafier',
#  'Italia',
#  'Jean-Jacques_Rousseau',
#  'Juf',
#  'Jura_(chadaina)',
#  'Kasachstan',
#  'Kiev',
#  'Kongeriket_Noreg',
#  'Kongeriket_Norge',
#  'Lai',
#  'Laresch',
#  'Leopard',
#  'Lettonia',
#  'Liberalissem',
#  'Liechtenstein',
#  'Lingua_bretona',
#  'Lingua_ladina',
#  'Lingua_taliana',
#  'Linguas_europeicas',
#  'Lissabon',
#  'Lituania',
#  'Liun',
#  'Ljubljana',
#  'Londra',
#  'Ludra',
#  'Luf',
#  'Luxemburg',
#  'Macedonia_dal_Nord',
#  'Madrid',
#  'Malta',
#  'Mar_Adriatic',
#  'Mar_Adriatica',
#  'Mar_Caspica',
#  'Mar_Mediterrana',
#  'Mar_Nair',
#  'Mar_Naira',
#  'Mar_da_l%27Ost',
#  'Mar_mediterran',
#  'Martin_Luther_King',
#  'Marxissem',
#  'Migraziun_dals_utschels',
#  'Minsk',
#  'Misarogns',
#  'Moldavia',
#  'Monaco',
#  'Montenegro',
#  'Moscau',
#  'Muntogna',
#  'NATO',
#  'Naziunalissem',
#  'Neutralitad_svizra',
#  'Noreg',
#  'Norge',
#  'Norvegia',
#  'Ogn_nair',
#  'Ogn_verd',
#  'Ollanda',
#  'Organisaziun_per_la_segirezza_e_la_cooperaziun_en_l%27Europa',
#  'Oslo',
#  'Pajais_Bass',
#  'Paraula',
#  'Paris',
#  'Peninsla_dal_Balcan',
#  'Peter_Ren%C3%A9_Baumann',
#  'Pign',
#  'Planta_(bostg)',
#  'Politica',
#  'Pologna',
#  'Polska',
#  'Populaziun_mundiala',
#  'Portg_selvadi',
#  'Portugal',
#  'Poschiavo',
#  'Prag',
#  'Preistorgia',
#  'Principadi_dal_Liechtenstein',
#  'Pr%C3%BCma_Guerra_mundiela',
#  'Punts',
#  'Puschlav',
#  'Puschlev',
#  'Pusclev',
#  'Quacra',
#  'Quacra_europeica',
#  'Rassissem',
#  'Reginavel_Un%C3%AC',
#  'Reginavel_Un%C3%AC_da_la_Gronda_Britannia_ed_Irlanda_dal_Nord',
#  'Reginavel_un%C3%AC_da_la_Gronda_Britannia_ed_Irlanda_dal_Nord',
#  'Regiunalissem',
#  'Religiun',
#  'Republica_da_l%27Irlanda',
#  'Restauraziun',
#  'Revoluziun_americana',
#  'Revoluziun_franzosa',
#  'Revoluziun_tudestga_dal_1848/49',
#  'Riga',
#  'Rinoceros_nair',
#  'Roma',
#  'Ruma',
#  'Rumenia',
#  'Russia',
#  'Ruver_cumin',
#  'Ruver_puschl%C3%A0',
#  'Safari',
#  'Salesch_alv',
#  'San_Marino',
#  'Scandinavia',
#  'Schah',
#  'Schweiz',
#  'Scozia',
#  'Scumbigls_grischuns',
#  'Scumpigls_grischuns',
#  'Serbia',
#  'Silena_cumina',
#  'Slovachia',
#  'Slovenia',
#  'Societad_da_las_naziuns',
#  'Sofia',
#  'Sorber_grond',
#  'Spagna',
#  'Stadi',
#  'Stadi_da_la_Citad_dal_Vatican',
#  'Stadi_dal_Vatican',
#  'Stadi_vatican',
#  'Stadis_Unids',
#  'Stadis_Unids_da_l%27America',
#  'Stockholm',
#  'Suisse',
#  'Svezia',
#  'Svizra',
#  'Svizzera',
#  'Switzerland',
#  'Tais',
#  'Taisch',
#  'Talian',
#  'Targnol',
#  'Telegrafia',
#  'Telesguard',
#  'Telpi',
#  'Temp_da_bronz',
#  'Temp_da_crap',
#  'Temp_medieval',
#  'Temp_medieval_tardiv',
#  'Temp_medieval_tempriv',
#  'Temp_modern_tempriv',
#  'Terra',
#  'Territori_natiral_proteg%C3%AC',
#  'The_Beatles',
#  'Tiaratudestga',
#  'Tieu_da_guaud',
#  'Tigl_d%27enviern',
#  'Tirchia',
#  'Trembel',
#  'Trembel_nair',
#  'Tschechia',
#  'Tschilendra',
#  'Tsch%C3%A9ss-barbet',
#  'Tur_d%27Eiffel',
#  'UEFA',
#  'USA',
#  'Ucraina',
#  'Ulm_champester',
#  'Ulm_da_muntogna',
#  'Ungaria',
#  'United_Kingdom_of_Great_Britain_and_Northern_Ireland',
#  'Uniun_internaziunala_per_il_mantegniment_da_la_natira_e_da_sias_resursas',
#  'Vaduz',
#  'Valisa',
#  'Varsovia',
#  'Vatican',
#  'Vienna',
#  'Vikings',
#  'Volga',
#  'Vulp',
#  'Wien',
#  'Wolga',
#  'Zagreb',
#  'Africa',
#  'Albania',
#  'Alps',
#  'Amsterdam',
#  'Andorra',
#  'Andorra_la_Vella',
#  'Armenia',
#  'Aserbeidschan',
#  'Asia',
#  'Associaziun_europeica_da_commerzi_liber',
#  'Athen',
#  'Atlantic',
#  'Augustus',
#  'Australia',
#  'Austria',
#  'Barcelona',
#  'Belgia',
#  'Belgrad',
#  'Berlin',
#  'Berna',
#  'Bielorussia',
#  'Bosnia-Erzegovina',
#  'Bosnia_ed_Erzegovina',
#  'Bratislava',
#  'Br%C3%BCssel',
#  'Bucarest',
#  'Budapest',
#  'Bulgaria',
#  'Canada',
#  'Carl_il_Grond',
#  'Chi%C8%99in%C4%83u',
#  'Cipra',
#  'Citad_dal_Vatican',
#  'Cosovo',
#  'Cristianissem',
#  'Croazia',
#  'Cussegl_da_l%27Europa',
#  'Danemarc',
#  'Dublin',
#  'Emprima_Guerra_mundiala',
#  'Engalterra',
#  'Estonia',
#  'Finlanda',
#  'Frantscha',
#  'Germania',
#  'Grezia',
#  'Guerra_da_trent%27onns',
#  'Guerra_fraida',
#  'Guerras_da_coaliziun',
#  'Hamburg',
#  'Helsinki',
#  'Illuminissem',
#  'Irlanda',
#  'Islam',
#  'Islanda',
#  'Istanbul',
#  'Istorgia_da_l%27Europa',
#  'Italia',
#  'Kasachstan',
#  'Kiev',
#  'Lettonia',
#  'Liechtenstein',
#  'Lissabon',
#  'Lituania',
#  'Ljubljana',
#  'Londra',
#  'Luxemburg',
#  'Macedonia_dal_Nord',
#  'Madrid',
#  'Malta',
#  'Mar_Caspica',
#  'Mar_Mediterrana',
#  'Mar_Naira',
#  'Milaun',
#  'Minca',
#  'Minsk',
#  'Moldavia',
#  'Monaco',
#  'Montenegro',
#  'Moscau',
#  'NATO',
#  'Napoli',
#  'New_York',
#  'Norvegia',
#  'Organisaziun_per_la_segirezza_e_la_cooperaziun_en_l%27Europa',
#  'Oslo',
#  'Pajais_Bass',
#  'Paris',
#  'Pologna',
#  'Portugal',
#  'Prag',
#  'Reginavel_Un%C3%AC',
#  'Republica_da_l%27Irlanda',
#  'Revoluziun_franzosa',
#  'Riga',
#  'Roma',
#  'Rumenia',
#  'Russia',
#  'San_Marino',
#  'Segunda_Guerra_mundiala',
#  'Serbia',
#  'Slovachia',
#  'Slovenia',
#  'Sofia',
#  'Spagna',
#  'Stockholm',
#  'Svezia',
#  'Svizra',
#  'Tirchia',
#  'Tokio',
#  'Tschechia',
#  'Ucraina',
#  'Ungaria',
#  'Uniun_europeica',
#  'Uniun_sovietica',
#  'Vaduz',
#  'Varsovia',
#  'Vatican',
#  'Vienna',
#  'Volga',
#  'Zagreb']

# %%
deg = list(G.degree)
deg.sort(key = operator.itemgetter(1))
print(deg)
# Out:
# [('Blienzilver', 0), ('HDMI', 0), ('High-Definition_Multimedia_Interface', 0), ('High_Definition_Multimedia_Interface', 0), ('Hoe%3F_Zo!', 0), ('Infobox:Weg_in_Ieslaand', 0), ('Kontaktleans', 0), ('Pluto', 0), ('Schroeve', 0), ('Sollenpeper', 0), ('Vogelnoamen_Nederlands-Grunnegs', 0), ('V%C3%B6%C3%A4rblad_(ANS)', 0), ('Webkroeper', 0), ('Willem_V', 0), ('Zuud', 0), ('Aalkruud', 1), ('Aambeeld', 1), ('Aeolische_%C3%B4fzetten', 1), ('Alatri', 1), ('Ambeeld', 1), ('Amsterdamsche_Veld', 1), ('Amsterdamscheveld', 1), ('Antwaarpen', 1), ('Antwarpen', 1), ('Anubis', 1), ('Aolkruud', 1), ('Ask_en_Embla', 1), ('Assimilasie_(Sproakleer)', 1), ('Assimilasie_(sproakleer)', 1), ('Australi%27je', 1), ('Avvekaot', 1), ('Baarlo', 1), ('Baka', 1), ('Balke', 1), ('Banke', 1), ('Bat', 1), ('Bates_Motel', 1), ('Bertha_Benz', 1), ('Beskuul', 1), ('Blaerteken', 1), ('Blearteken', 1), ('Bloedbleer', 1), ('Bloempot', 1), ('Bloomendaal', 1), ('Boeket', 1), ('Bontebok', 1), ('Boom_(deurverwiespagina)', 1), ('Bourgondisch', 1), ('Bremen_(deurverwiespagina)', 1), ('Bruker:Ptbotgourou', 1), ('Buukspieker', 1), ('Caselle_Landi', 1), ('Creative_Commons', 1), ('De_Driesprong', 1), ('De_Haar', 1), ('De_Haule', 1), ('De_Leeuwte', 1), ('De_Penne', 1), ('De_Polle', 1), ('Delaware_County', 1), ('Depressie', 1), ('Doebai', 1), ('Dorset', 1), ('Drumpel', 1), ('Eschweiler', 1), ('Femilie', 1), ('Filips_II', 1), ('Gallerieje', 1), ('Gemeante', 1), ('Gemeeinte', 1), ('Geografische_ko%C3%B6rdinaoten', 1), ('Geografische_ko%C3%B6rdinaten', 1), ('Poldernederlaands', 1), ('Grezzelet', 1), ('Grunny', 1), ('Gunees_Keuntjen', 1), ('Gunees_keuntjen', 1), ('Haart', 1), ('Willem_III', 1), ('Haonepoot', 1), ('Haren', 1), ('Hartogdomme', 1), ('Haule', 1), ('Heemstede', 1), ('Heern', 1), ('Herik', 1), ('Hering', 1), ('Het', 1), ('Hieronymus', 1), ('Hulk', 1), ('Indo-Europese_rilligie', 1), ('Jaap_Meijer', 1), ('Jajem', 1), ('Jonen', 1), ('Karen', 1), ('Keuning', 1), ('Klark', 1), ('Klosse', 1), ('Kluus', 1), ('Knien', 1), ('Kniende', 1), ('Koaperbreef', 1), ('Kouwe', 1), ('Kranenburg', 1), ('Kreool', 1), ('K%C3%A5rel_de_Groute', 1), ('K%C3%B6nning', 1), ('Lagos', 1), ('Leek', 1), ('Leeuwte', 1), ('Life_After_People', 1), ('Loppersom', 1), ('L%C3%A5res', 1), ('Maalte', 1), ('Maarkisch', 1), ('Macedonie', 1), ('Meanse,_durf_te_leven', 1), ('Meanse,_d%C3%B6rf_te_leven', 1), ('Meksiko', 1), ('Mercurius', 1), ('Merkurius', 1), ('Moldavi%C3%AB', 1), ('Mondorgel', 1), ('Montana_(duurverwiesziede)', 1), ('Moodswinger', 1), ('Neptunus', 1), ('Neuschwanstein', 1), ('Ni%27je_Vaort', 1), ('Ni%27jebrogge', 1), ('Nuth', 1), ('OLD', 1), ('Oale_Edda', 1), ('Oberon', 1), ('Peupe', 1), ('Piepe', 1), ('Pigazzano', 1), ('Piraat', 1), ('Plataan', 1), ('Pol', 1), ('Qu%C3%A9bec', 1), ('Rekkenmesiene', 1), ('Reuznpanda', 1), ('Riepe', 1), ('Rohel', 1), ('Rolmoate', 1), ('Ryan_Farish', 1), ('SSID', 1), ('Sangklokke', 1), ('Saturnus', 1), ('Schaans', 1), ('Schoakelketten', 1), ('Sint-Gregoriuskarke', 1), ('Sint-Martinus', 1), ('Sint-Meerten', 1), ('Sint_Maarten', 1), ('Sjarpe', 1), ('Stientje', 1), ('Stoelnmatter', 1), ('Stroe', 1), ('Sukerfeest', 1), ('Sunte-Marten', 1), ('Sunte-Meerten', 1), ('Sunte_Matt%27n', 1), ('Telmesiene', 1), ('Texas_Hold%27em', 1), ('The_X-Files', 1), ('Til', 1), ('Titanic', 1), ('Toetsenbord', 1), ('Trekker_Trek', 1), ('Trekkersl%C3%A8p', 1), ('Trente', 1), ('Truus', 1), ('Turfsteken', 1), ('T%C3%B6rf_stikken', 1), ('Uranus', 1), ('Utrechs', 1), ('VRT', 1), ('Valbrugge', 1), ('Veldwiek', 1), ('WEV', 1), ('Wasbod_(boek)', 1), ('Werlddag_van_de_oceanen', 1), ('Westerdaipsterdale', 1), ('Wetering', 1), ('Willem_I', 1), ('Willemsoord', 1), ('Winsum', 1), ('Winzum', 1), ('Wissel', 1), ('World_Wide_Fund_for_Nature', 1), ('ZW', 1), ('Zeum', 1), ('Zoalt', 1), ('Zwijndrecht', 1), ('%C5%A0iprage', 1), ('Vlagtwedde', 2), ('2_(getal)', 2), ('30_Seconds_to_Mars', 2), ('Aan_de_rand_van_Hollands_gouwen', 2), ('Achterhooks_volkslied', 2), ('Aldeyjarfoss', 2), ('Angelus', 2), ('Wees-egroet', 2) ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)
# print "Degree sequence", degree_sequence
dmax = max(degree_sequence)

plt.loglog(degree_sequence, 'b-', marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")


plt.show()

plt.savefig("degree_histogram_duthc.png")

# %%
from operator import itemgetter

import matplotlib.pyplot as plt
import networkx as nx

if __name__ == '__main__':
    # Create a BA model graph
    n = 1000
    m = 2
    # find node with largest degree
    node_and_degree = G.degree()
    (largest_hub, degree) = sorted(node_and_degree, key=itemgetter(1))[-1]
    # Create ego graph of main hub
    hub_ego = nx.ego_graph(G, largest_hub)
    # Draw graph
    pos = nx.spring_layout(hub_ego)
    nx.draw(hub_ego, pos, node_color='b', node_size=20, width=0.5, with_labels=False)
    # Draw ego as large and red
    nx.draw_networkx_nodes(hub_ego, pos, nodelist=[largest_hub], node_size=50, node_color='r')
    plt.show()
    plt.savefig('dutch_mainnode.png', dpi=400)
